# %%
import data_query as dq
import testing_process as tp
import importlib
import pandas as pd
importlib.reload(dq)
importlib.reload(tp)
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# TODO: find best way for detail label-message-count-category-suggestion for multiple label/message

# %%
df = tp.db_connect(tp.final_query)

# %%
# 1. Send to repair station with single label and single message
# 2. Send to repair station with single label and multiple messages

# 3. Send to repair station but no correspond label from failure description and directly extract label/message from symptom_info
# 4. Send to repair station but no symptom_info or symptom_info is {}, dict will be {failure_description:""}
# 5. Send to repair station but message is empty, dict will be {failure_description:""}
# 6. Not send to repair station, no correspond label from failure description and directly extract label/message from symptom_info
'''
Included Cases: 
1. Matched failure description and symptom_label, with single correspond message
2. Matched failure description and symptom_label, with multiple correspond message
3. Empty failure description, include every label-message from symptom_dict
4. No match failure description, include every label-message from symptom_dict
'''
result_df = tp.process_symptom_info(df)

# %%
processed_result_df = tp.compute_label_cycles(result_df)

# %%
new = processed_result_df[['serial_number', 'testing_date', 'repaired_date', 'label_cycle']]
new = new[new['testing_date']<='2025-03-31']

# %%
# Step 1: 計算所有 label 的總次數
total_counter = Counter()
for cycle in new["label_cycle"]:
    total_counter.update(cycle)

# Step 2: Top 10 label 出現總次數
top_labels = [label for label, _ in total_counter.most_common(10)]
top_10_counter = {label: total_counter[label] for label in top_labels}
top_10_total = sum(top_10_counter.values())

# Step 3: 所有 label 出現總次數
overall_total = sum(total_counter.values())

# Step 4: 百分比
percentage_top10 = top_10_total / overall_total

top_10_counter, overall_total, round(percentage_top10 * 100, 2)
# Out:
# ({'hb16 pcie link speed and width check': 3166,
#   'diorite ssh connection failed': 3048,
#   'checking bmc boot readiness and get bmc ip failed': 2683,
#   'dimm infos validation failure': 2542,
#   'fru infos validation failure': 1290,
#   'sdc first fail of test-completion-missing-error for retest': 1141,
#   'diorite location validation failure': 886,
#   'the sensor count of config_check_hw is not matched.': 872,
#   'capture diorite console and attach to log failed': 773,
#   'diorite pcie link speed and width check': 758},
#  25633,
#  66.94)

# %%
from collections import Counter

# 1. 找出所有 label 出現頻率（Across all SNs）
all_label_counter = Counter()
for cycle in new["label_cycle"]:
    all_label_counter.update(cycle.keys())

# 2. 取出 top N label 作為「改善對象」
top_labels = [label for label, _ in all_label_counter.most_common(10)]  # 可以調整 top 5/10

# 3. 建立 "改善後的筆數"（假設這些 top label 不再重複）
def adjusted_count(label_dict, fixed_labels):
    count = 0
    for label, freq in label_dict.items():
        if label in fixed_labels:
            count += min(freq, 1)  # 視為只修一次
        else:
            count += freq  # 沒改善的照舊
    return count

# 4. 計算 Before & After cycle 數量（總筆數）
new["original_cycle"] = new["label_cycle"].apply(lambda d: sum(d.values()))
new["adjusted_cycle"] = new["label_cycle"].apply(lambda d: adjusted_count(d, top_labels))

# 5. 加入 duration
new["repaired_date"] = pd.to_datetime(new["repaired_date"])
new["testing_date"] = pd.to_datetime(new["testing_date"])
new["repair_duration"] = (new["repaired_date"] - new["testing_date"]).dt.total_seconds() / 60
avg_duration = new["repair_duration"].mean()

# 6. groupby SN：before/after 總維修時間
original_cycle_avg = new.groupby("serial_number")["original_cycle"].sum().mean()
adjusted_cycle_avg = new.groupby("serial_number")["adjusted_cycle"].sum().mean()

# 7. repair 時間估算
original_time_avg = original_cycle_avg * avg_duration
adjusted_time_avg = adjusted_cycle_avg * avg_duration

# %%
original_cycle_avg,adjusted_cycle_avg,original_time_avg,adjusted_time_avg,avg_duration
# Out:
# (np.float64(2.3670699048850308),
#  np.float64(1.8828146643272694),
#  np.float64(8143.584425762396),
#  np.float64(6477.569650718586),
#  np.float64(3440.3649883580147))

# %%
1 - adjusted_time_avg/original_time_avg
# Out:
# np.float64(0.20458003355050125)

# %%
# Define the keyword to search for
keyword_to_drop = "checking bmc"  # Change this to the actual keyword

# Function to check if the keyword exists in the dictionary keys
def contains_keyword(symptom_dict, keyword):
    if not isinstance(symptom_dict, dict):  # Ensure it's a valid dictionary
        return False
    return any(keyword in label for label in symptom_dict.keys())  # Check if keyword is in any label

# Drop rows where the keyword appears in symptom_dict keys
check_bmc_df = processed_result_df[processed_result_df["symptom_dict"].apply(lambda x: contains_keyword(x, keyword_to_drop))]

# %%
# Define the keyword to search for
keyword_to_drop = "rsync-error"  # Change this to the actual keyword

# Function to check if the keyword exists in the dictionary keys
def contains_keyword(symptom_dict, keyword):
    if not isinstance(symptom_dict, dict):  # Ensure it's a valid dictionary
        return False
    return any(keyword in label for label in symptom_dict.keys())  # Check if keyword is in any label

# Drop rows where the keyword appears in symptom_dict keys
processed_result_df = processed_result_df[~processed_result_df["symptom_dict"].apply(lambda x: contains_keyword(x, keyword_to_drop))]

# %%
debug_df = pd.read_excel('debug_tree.xlsx', header=[0, 1])
# Rename columns properly
debug_df.columns = ["symptom_label", "symptom_message", "cycle1_cat", "cycle1_suggestion", "cycle2_cat", "cycle2_suggestion", "cycle3+_cat", "cycle3+_suggestion"]
# Fill down `symptom_label` column and apply stripping/lowering
debug_df["symptom_label"] = debug_df["symptom_label"].ffill().str.strip().str.lower()

# Apply stripping and lowering to `symptom_message` column
debug_df["symptom_message"] = debug_df["symptom_message"].astype(str).str.strip().str.lower()
unique_pairs_set = set(zip(debug_df["symptom_label"], debug_df["symptom_message"]))
len(unique_pairs_set), len(set(debug_df["symptom_label"]))
# Out:
# (367, 180)

# %%
# Split to single label-message set and multi label-message set
single_label = processed_result_df[processed_result_df['label_cycle'].apply(lambda x: len(x) == 1)]
multi_label = processed_result_df[processed_result_df['label_cycle'].apply(lambda x: len(x) > 1)] # cases of no failure description
single_label_message = single_label[single_label['label_message_cycle'].apply(lambda x: len(x) == 1)]
single_label_multi_message = single_label[single_label['label_message_cycle'].apply(lambda x: len(x) > 1)]

# %%
hb16_patterns = [rf"device not found\.\s*can't validate pcie info for 'pe{pe}.io0'"for pe in range(2, 6)]
pcie_pelane_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'lane_error' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpulane_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'lane_error' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

pcie_pereceiver_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'receiver_error' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpureceiver_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'receiver_error' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

pcie_pereplay_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'replay_timer_timeout' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpureplay_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'replay_timer_timeout' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

sensor_fan_tach_patterns = [
    rf"^got \d+ violations, exceeding threshold of \d+ for sensor fan{fan} tach\."
    for fan in range(0, 6) 
]

match_criteria = {
    'memtester-insufficient-memory': "available memory: \d+, minimum required memory: \d+",
    "capture diorite console and attach to log failed":  r"^caught .*? exception",
    "sata fio write too slow": [r"sata fio /dev/sda (read|write) bw too slow,? cur: \d+, exp: \d+"],  # Label regex
    "sata fio log check": [r'(?s)(?=.*"fio version")(?=.*"timestamp")(?=.*"timestamp_ms")(?=.*"time")'],  # Message regex
    "command execution failed date": [r"command execution failed: date"], # Label regex
    "command execution failed date message": [r"exception message"], # Message regex
    "dimm infos validation failure": r"component dimm sn: .*? not found on unit",
    "hb16 pcie link speed and width check": hb16_patterns,
    "diorite location validation failure": [r"component diorite sn: .*? not found on unit",r"component diorite sn \S+ location: \S+, expected location: \S+"],
    "pcierrors-high-lane_error-rate": pcie_pelane_patterns + pcie_cpulane_patterns,
    "pcierrors-high-receiver_error-rate": pcie_pereceiver_patterns + pcie_cpureceiver_patterns,
    "pcierrors-high-replay_timer_timeout-rate": pcie_pereplay_patterns + pcie_cpureplay_patterns,
    "lower critical limit violated": sensor_fan_tach_patterns,
    "hb16 location validation failure": [r"component hb16 sn: .*? not found on unit",r"component hb16 sn \S+ location: \S+, expected location: \S+"],
    "error-monitor-procedural-error": r"^Test failed:.*?INTERNAL:",
    "diorite part number": r"value\s*=\s*['\"]([^'\"]+)['\"]\s*lower_limit\s*=\s*['\"]([^'\"]*)['\"]\s*upper_limit\s*=\s*['\"]([^'\"]*)['\"]",
    "send command fail:\s*stressapptest": "exception message:\s*\ntraceback",
    "diorite ssh connection failed": "create diorite ssh connection failed\.\s*can not connect to diorite ip: ",
    "cpu location validation failure": [r"component cpu sn: .*? not found on unit",r"component cpu sn \S+ location: \S+, expected location: \S+"],
    "timeout exceeded.": r"thread .*? execution exceeded the timeout limit of .*? seconds",
    "attach booting logs to otc failed": r"attach booting logs to otc failed.\nmsg:",
    "caught oserror exception.": r"traceback \(most recent call last\):\n.*",
    "dimm location validation failure": r"component dimm sn .+? location: .+?, expected location: .+?",
    "io adapter location validation failure": r"component io adapter sn .+? location: .+?, expected location: .+?",
    "gssd location validation failure": [r"component gssd sn: .*? not found on unit",r"component gssd sn \S+ location: \S+, expected location: \S+"],
    "cssd infos validation failure": r"component cssd sn: .*? not found on unit",
    "configuration check (hardware) failed": r"parse response failure. response:",
    "configuration check (software) failed": r"send command",
    "bad-bus": r"for local bus.*?/phys/cpu\d+.*?expected speed:.*?, actual speed:"
}
# Ensure all match_criteria values are lists of patterns
match_criteria = {key: [value] if isinstance(value, str) else value for key, value in match_criteria.items()}

# %%
merged_symptoms_list = []
for symptom_data in processed_result_df["symptom_dict"]:
    if not isinstance(symptom_data, dict):  # Skip non-dict values
        continue
    for label, messages in symptom_data.items():
        # Ensure messages is always a list
        if isinstance(messages, str):  
            messages = [messages]  # Convert single string to list

        for message in messages:
            merged_symptoms_list.append({"symptom_label": label, "symptom_message": message})

# Create DataFrame
merged_symptoms_df = pd.DataFrame(merged_symptoms_list).drop_duplicates().reset_index(drop=True)

# %%
# Use groupby() + to_dict() for a much faster dictionary creation
debug_dict = debug_df.groupby("symptom_label")["symptom_message"].apply(set).to_dict()

# %%
import time
import re

# Step 1: Precompile all regex patterns
compiled_match_criteria = {
    key: [re.compile(p, re.IGNORECASE) for p in patterns] for key, patterns in match_criteria.items()
}

# Step 2: Initialize tracking list for slow rows
slow_indices = []  # Stores indices of rows taking too long

MAX_LENGTH = 500  # Set an appropriate limit

# Step 3: Define regex match function
def regex_match(text, compiled_patterns, timeout=1.0):
    """Checks if text matches any precompiled regex pattern from a dictionary."""
    if pd.isna(text):
        return False
    
    # If the message is too long, only match the first 500 characters
    text = text[:500] if len(text) > 500 else text

    start_time = time.time()
    for label, patterns in compiled_patterns.items():  # ✅ Loop through correctly
        for pattern in patterns:
            if time.time() - start_time > timeout:
                return False  # Skip slow matches
            if pattern.search(text):
                return True  # ✅ Found a match

    return False

# Step 4: Compute label match efficiently
merged_symptoms_df["label_match_flag"] = merged_symptoms_df["symptom_label"].map(
    lambda label: label in debug_dict or regex_match(label, compiled_match_criteria)
)

# Step 5: Compute full match (Skip slow rows)
def fast_full_match(row, timeout=1.0):
    """Checks if symptom_label + symptom_message match exactly or via regex (only if needed)."""
    label, message = row["symptom_label"], row["symptom_message"]

    if row["label_match_flag"]:
        # Exact message match
        if label in debug_dict and message in debug_dict[label]:
            return True

        # If message is too long, try regex on the first 500 characters
        if len(message) > MAX_LENGTH:
            if regex_match(message[:500], compiled_match_criteria, timeout=timeout):
                return True
            slow_indices.append(row.name)  # Store row index if still slow
            return False  # Skip row

        # Otherwise, check regex on the full message
        start_time = time.time()
        if regex_match(message, compiled_match_criteria, timeout=timeout):
            return True

        elapsed_time = time.time() - start_time
        if elapsed_time > timeout:
            slow_indices.append(row.name)  # Store slow row index
            return False  # Skip slow row

    return False  # No match if label itself is unmatched

# Step 6: Apply fast matching with timeout
merged_symptoms_df["full_match_flag"] = merged_symptoms_df.apply(lambda row: fast_full_match(row, timeout=1.0), axis=1)

# %%
# Step 1: Precompile all regex patterns
compiled_match_criteria = {
    key: [re.compile(p, re.IGNORECASE) for p in patterns] for key, patterns in match_criteria.items()
}

# Step 2: Convert merged_symptoms_df into a lookup dictionary for quick matching
merged_label_set = set(merged_symptoms_df["symptom_label"])
merged_message_dict = (
    merged_symptoms_df.groupby("symptom_label")["symptom_message"].apply(set).to_dict()
)

# Step 3: Define regex match function
def regex_match(text, compiled_patterns, timeout=1.0):
    """Checks if text matches any precompiled regex pattern from a dictionary."""
    if pd.isna(text):
        return False
    
    text = text[:500] if len(text) > 500 else text  # Limit length

    start_time = time.time()
    for label, patterns in compiled_patterns.items():
        for pattern in patterns:
            if time.time() - start_time > timeout:
                return False  # Skip slow matches
            if pattern.search(text):
                return True

    return False

# Step 4: Compute label and full match flags for debug_df
def check_label_match(label):
    """Check if the label exists in merged_symptoms_df or matches a regex."""
    return label in merged_label_set or regex_match(label, compiled_match_criteria)

def check_full_match(row):
    """Check if both label and message match."""
    label, message = row["symptom_label"], row["symptom_message"]
    
    # ✅ Check exact label-message match in merged_symptoms_df
    if label in merged_message_dict and message in merged_message_dict[label]:
        return True

    # ✅ Check regex match for message (if label is already matched)
    if row["label_match_flag"]:
        return regex_match(message, compiled_match_criteria)

    return False

# Step 5: Create solved_debug_df
solved_debug_df = debug_df.copy()

# Step 6: Apply matching checks
solved_debug_df["label_match_flag"] = solved_debug_df["symptom_label"].apply(check_label_match)
solved_debug_df["full_match_flag"] = solved_debug_df.apply(check_full_match, axis=1)
solved_debug_df[["symptom_label", 'symptom_message', "label_match_flag", "full_match_flag"]].to_csv('solved_debug_df.csv', index=False)

# %%
print("solved percentage for fully match from debug tree: ", merged_symptoms_df[(merged_symptoms_df['label_match_flag']==True)&(merged_symptoms_df['full_match_flag']==True)].shape[0] / merged_symptoms_df.shape[0])
print("found label: ", len(merged_symptoms_df[merged_symptoms_df['label_match_flag']==True].symptom_label.unique()) / len(merged_symptoms_df.symptom_label.unique()))
# Out:
# solved percentage for fully match from debug tree:  0.8046396887897908
# found label:  0.5521172638436482

# %%
merged_symptoms_df
# Out:
#                                            symptom_label  \
# 0                           ncsi_cable-preparation-error
# 1      the sensor count of config_check_hw is not mat...
# 2                           check dut connections failed
# 3            hb16 pcie link speed and width check failed
# 4                          dimm infos validation failure
# ...                                                  ...
# 21074                      diorite ssh connection failed
# 21075                      dimm infos validation failure
# 21076                diorite location validation failure
# 21077                      diorite ssh connection failed
# 21078                      diorite ssh connection failed
#
#                                          symptom_message  label_match_flag  \
# 0              failed to detect ncsi cable on diorite cn              True
# 1      total number of sensors expected: 185, current...              True
# 2              check symptom message of each step below.             False
# 3      device not found.\ncan't validate pcie info fo...              True
# 4      component dimm sn: (l)64gb 2rx4 pc5-4800b-ra0-...              True
# ...                                                  ...               ...
# 21074  create diorite ssh connection failed.\ncan not...              True
# 21075  component dimm sn: (l)64gb 2rx4 pc5-5600b-ra0-...              True
# 21076  component diorite sn: pdfcth250413850 not foun...              True
# 21077  create diorite ssh connection failed.\ncan not...              True
# 21078  create diorite ssh connection failed.\ncan not...              True
#
#        full_match_flag
# 0                 True
# 1                False
# 2                False
# 3                 True
# 4                 True
# ...                ...
# 21074             True
# 21075             True
# 21076             True
# 21077             True
# 21078             True
#
# [21079 rows x 4 columns]

# %%
# Count the number of unique symptom_message per symptom_label
# Labels that are not on the debug tree, what need to be delete or add!?
not_match_df = merged_symptoms_df[merged_symptoms_df['label_match_flag']==False]
label_message_count = not_match_df.groupby("symptom_label")["symptom_message"].nunique().reset_index()
print(not_match_df.shape)
label_message_count.sort_values(by=['symptom_message'], ascending=False)
# Out:
# (912, 4)
#                                          symptom_label  symptom_message
# 250                   sensor-monitor-runtime-too-short              128
# 248  sdc first fail of test-completion-missing-erro...               81
# 42                         diorite sanity check failed               69
# 246                                 sat-tolerable-dimm               24
# 24                                                cssd               24
# ..                                                 ...              ...
# 266                       the gulp it's not functional                1
# 264                     the count of gulp fru is not 1                1
# 263                 the cable pcle it's not functional                1
# 5                                    ampttkv30-timeout                1
# 4                  also need to swap dimm20 and dimm18                1
#
# [275 rows x 2 columns]

# %%
not_match_message_df = merged_symptoms_df[(merged_symptoms_df['label_match_flag']==True)&(merged_symptoms_df['full_match_flag']==False)]
print(not_match_message_df.shape)
label_message_count = not_match_message_df.groupby("symptom_label")["symptom_message"].nunique().reset_index()
print(label_message_count.shape)
label_message_count.sort_values(by=['symptom_message'], ascending=False)[:10]
# Out:
# (3206, 4)
# (89, 2)
#                                         symptom_label  symptom_message
# 33                       fru infos validation failure             1975
# 25            excessive-uncorrectable-core-cpu-errors               87
# 47            pcierrors-high-surprise_down_error-rate               81
# 41                        pcierrors-high-bad_tlp-rate               76
# 4                                             bad-bus               74
# 34                   gssd location validation failure               63
# 36                      lower critical limit violated               61
# 75  the sensor count of config_check_hw is not mat...               58
# 79                              unknown-pcie-location               48
# 30                           fan_speed-internal-error               47

# %%
aa = not_match_message_df[not_match_message_df['symptom_label'].str.contains('hb16')]
text = aa.iloc[1].symptom_message
print(text)
aa
# Out:
# pcie device existence on 'pe3.io0'
#                               symptom_label  \
# 8441   hb16 pcie link speed and width check
# 8442   hb16 pcie link speed and width check
# 8443   hb16 pcie link speed and width check
# 8444   hb16 pcie link speed and width check
# 8992   hb16 pcie link speed and width check
# 8993   hb16 pcie link speed and width check
# 8994   hb16 pcie link speed and width check
# 9064   hb16 pcie link speed and width check
# 9065   hb16 pcie link speed and width check
# 10045  hb16 pcie link speed and width check
# 17178  hb16 pcie link speed and width check
#
#                                          symptom_message  label_match_flag  \
# 8441                  pcie device existence on 'pe4.io0'              True
# 8442                  pcie device existence on 'pe3.io0'              True
# 8443                  pcie device existence on 'pe2.io0'              True
# 8444                  pcie device existence on 'pe5.io0'              True
# 8992   pcie device link width at /phys/pe2/io0:device...              True
# 8993   pcie device link width at /phys/pe5/io0:device...              True
# 8994   pcie device link width at /phys/pe3/io0:device...              True
# 9064   pcie device link width at /phys/pe4/io0:device...              True
# 9065   pcie device link speed at /phys/pe3/io0:device...              True
# 10045  pcie device link speed at /phys/pe2/io0:device...              True
# 17178  pcie device link speed at /phys/pe5/io0:device...              True
#
#        full_match_flag
# 8441             False
# 8442             False
# 8443             False
# 8444             False
# 8992             False
# 8993             False
# 8994             False
# 9064             False
# 9065             False
# 10045            False
# 17178            False

# %% [markdown]
# ## Deal with single label-message combination

# %%
singel_label_message_debug_result = tp.singel_label_message_debug(single_label_message, debug_df)

# %%
singel_label_message_debug_result.shape
# Out:
# (52913, 21)

# %%
def single_label_message_debug_with_pattern_matching(processed_result_df, debug_df, match_dict):
    """
    Updates processed_result_df by:
    1. Matching labels/messages using regex-based pattern matching.
    2. Tracking cycle counts per serial_number to ensure counts start at 1.
    3. Assigning category & suggestion based on debug_df.

    Parameters:
    - processed_result_df: DataFrame with label_cycle and label_message_cycle.
    - debug_df: DataFrame with symptom_label, symptom_message, and cycle-based category/suggestions.
    - match_dict: Dictionary containing regex patterns for label matching.

    Returns:
    - Updated DataFrame with new columns:
      - Category (dict)
      - Suggestion (dict)
      - Label_Cycle_Count (int)
      - Message_Cycle_Count (int)
    """

    processed_result_df_copy = processed_result_df.copy()

    # ✅ Step 1: Convert debug_df into a lookup dictionary
    debug_dict = {}
    for _, row in debug_df.iterrows():
        debug_label = row["symptom_label"]
        debug_message = row["symptom_message"]
        debug_dict.setdefault(debug_label, {})[debug_message] = row  # Store full row for lookup

    # ✅ Step 2: Initialize tracking for label & message counts per serial_number
    serial_label_count = {}  # {serial_number: {label_pattern: count}}
    serial_label_message_count = {}  # {serial_number: {(label_pattern, message): count}}

    # New columns to be added
    categories, suggestions = [], []
    label_cycle_counts, message_cycle_counts = [], []

    # ✅ Step 3: Iterate over `processed_result_df`
    for index, row in processed_result_df_copy.iterrows():
        serial_number = row["serial_number"]
        label_message_cycle = row["label_message_cycle"]  # Extract {(label, message): count}
        label_cycle = row["label_cycle"]  # Extract {label: count}

        # Initialize tracking for this serial_number if not exists
        if serial_number not in serial_label_count:
            serial_label_count[serial_number] = {}
            serial_label_message_count[serial_number] = {}

        category_dict, suggestion_dict = {}, {}

        # ✅ Initialize counts to ensure they are always assigned
        label_count = 1  # Default to 1 if no match found
        message_count = 1  # Default to 1 if no match found

        found_match = False  # Track if a match was found

        for (label, message), _ in label_message_cycle.items():
            matched_label = None

            # ✅ Step 4: Find matching label in `match_dict`
            for pattern_label in match_dict.keys():
                if re.fullmatch(pattern_label, label, re.IGNORECASE) or re.search(pattern_label, label, re.IGNORECASE):
                    matched_label = pattern_label
                    break  # Stop after first match

            if not matched_label:
                continue  # No match, skip

            found_match = True  # Mark that at least one match was found

            # ✅ Step 5: Determine cycle counts based on previous occurrences
            previous_label_counts = [
                count for prev_label, count in serial_label_count[serial_number].items()
                if re.fullmatch(matched_label, prev_label, re.IGNORECASE) or re.search(matched_label, prev_label, re.IGNORECASE)
            ]
            label_count = max(previous_label_counts) + 1 if previous_label_counts else 1  # Ensure first occurrence is 1

            previous_message_counts = [
                count for (prev_label, prev_message), count in serial_label_message_count[serial_number].items()
                if (re.fullmatch(matched_label, prev_label, re.IGNORECASE) or re.search(matched_label, prev_label, re.IGNORECASE))
                and prev_message == message  # Match message exactly
            ]
            message_count = max(previous_message_counts) + 1 if previous_message_counts else 1

            # ✅ Step 6: Store updated counts
            serial_label_count[serial_number][label] = label_count
            serial_label_message_count[serial_number][(label, message)] = message_count

            # ✅ Step 7: Assign category & suggestion based on cycle count
            if (label, message) in debug_dict:
                for i in [1, 2, "3+"]:
                    if message_count == i or (message_count >= 3 and i == "3+"):
                        category_dict[message] = debug_dict[(label, message)].get(f"cycle{i}_cat", "")
                        suggestion_dict[message] = debug_dict[(label, message)].get(f"cycle{i}_suggestion", "")

            elif label in debug_df["symptom_label"].values:
                for _, label_row in debug_df[debug_df["symptom_label"] == label].iterrows():
                    msg_text = label_row["symptom_message"]
                    for i in [1, 2, "3+"]:
                        if label_count == i or (label_count >= 3 and i == "3+"):
                            category_dict[msg_text] = label_row.get(f"cycle{i}_cat", "")
                            suggestion_dict[msg_text] = label_row.get(f"cycle{i}_suggestion", "")

        # ✅ Ensure `label_count` and `message_count` are at least 1 even if no match was found
        if not found_match:
            label_count = 1
            message_count = 1

        # ✅ Step 8: Append results
        categories.append(category_dict if category_dict else {})
        suggestions.append(suggestion_dict if suggestion_dict else {})
        label_cycle_counts.append(label_count)
        message_cycle_counts.append(message_count)


    # ✅ Step 9: Update DataFrame with new columns
    processed_result_df_copy["Category"] = categories
    processed_result_df_copy["Suggestion"] = suggestions
    processed_result_df_copy["Label_Cycle_Count"] = label_cycle_counts
    processed_result_df_copy["Message_Cycle_Count"] = message_cycle_counts

    return processed_result_df_copy

x = single_label_message_debug_with_pattern_matching(single_label_message[:5000], debug_df, match_criteria)

# %%
x
# Out:
#      model_name build_type    skuno  serial_number  \
# 0       ASTORIA         GA  1154500  FWI2345-00007
# 1       ASTORIA         GA  1154500  FWI2345-00007
# 2       ASTORIA         GA  1154500  FWI2345-00007
# 3       ASTORIA         GA  1154427  FWI2346-04932
# 4       ASTORIA         GA  1170765  FWI2348-00349
# ...         ...        ...      ...            ...
# 5482    ASTORIA         GA  1158438  FWI2409-15966
# 5483    ASTORIA         GA  1158438  FWI2409-15970
# 5484    ASTORIA         GA  1158438  FWI2409-15975
# 5485    ASTORIA         GA  1158438  FWI2409-15985
# 5486    ASTORIA         GA  1158438  FWI2409-15986
#
#                               station        repaired_date  \
# 0                 AST Functional Test  2023-11-15 15:58:55
# 1                 AST Functional Test  2023-11-15 15:58:55
# 2                 AST Functional Test  2023-11-15 15:58:55
# 3                 AST Functional Test  2023-11-21 11:04:41
# 4                        AST SDC Test  2023-12-01 12:00:31
# ...                               ...                  ...
# 5482                  AST Run-in Test  2024-03-04 08:52:34
# 5483              AST Functional Test  2024-03-04 13:48:15
# 5484              AST Functional Test  2024-03-03 09:24:49
# 5485              AST Functional Test  2024-03-04 19:48:36
# 5486  AST Google Firmware Update Test  2024-03-06 14:00:04
#
#                                            symptom_info  \
# 0     {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 1     {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 2     {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 3     {'SymptomRunKey_08aa141a-98e6-46be-bac5-4a590c...
# 4     {'SymptomRunKey_25d489b8-7ffc-468d-88a2-716c6a...
# ...                                                 ...
# 5482  {'SymptomRunKey_05d5b145-5aed-4fc2-adfb-1fec46...
# 5483  {'SymptomRunKey_95cb2e9c-d11c-48e8-b039-b477ea...
# 5484  {'SymptomRunKey_d7f0a55a-10cb-40d7-b30b-d2e9c1...
# 5485  {'SymptomRunKey_393c9e34-ed1e-4316-9826-4964fa...
# 5486  {'SymptomRunKey_188da5e6-61bf-40b1-be39-18bc7e...
#
#                                     failure_description    repair_code  \
# 0                          ncsi_cable-preparation-error  REPLACE- MOBO
# 1                          ncsi_cable-preparation-error   REPLACE- CPU
# 2                          ncsi_cable-preparation-error   REPLACE- CPU
# 3     The sensor count of Config_check_HW is not mat...         RETEST
# 4                          Check DUT connections Failed         RETEST
# ...                                                 ...            ...
# 5482                  test-completion-missing-error-sat         RETEST
# 5483                      DIMM infos validation failure  RESEAT - DIMM
# 5484                      DIMM infos validation failure    SWAP - DIMM
# 5485                      DIMM infos validation failure  RESEAT - DIMM
# 5486                          Update Google BIOS Failed         RETEST
#
#                                    repaired_description  ... no_match_flag  \
# 0     reseat ncsi; fail; replace ncsi; fail; reseat ...  ...         False
# 1                            replace mobo; replace cpu1  ...         False
# 2                            replace mobo; replace cpu0  ...         False
# 3     Terminal of conector with contamination, clean...  ...         False
# 4          power cycle, retest, Only 3 NIC ips detected  ...         False
# ...                                                 ...  ...           ...
# 5482                         unit unplugged during test  ...         False
# 5483                       DIMM23 not present reseated.  ...         False
# 5484              Reseat dimm 22 fail, swap with dimm 0  ...         False
# 5485                                     reseat dimm 21  ...         False
# 5486                                             Retest  ...         False
#
#       empty_symptom_flag  empty_message_flag  isRepair  \
# 0                  False               False      True
# 1                  False               False      True
# 2                  False               False      True
# 3                  False               False      True
# 4                  False               False      True
# ...                  ...                 ...       ...
# 5482               False               False      True
# 5483               False               False      True
# 5484               False               False      True
# 5485               False               False      True
# 5486               False               False      True
#
#                                             label_cycle  \
# 0                   {'ncsi_cable-preparation-error': 1}
# 1                   {'ncsi_cable-preparation-error': 2}
# 2                   {'ncsi_cable-preparation-error': 3}
# 3     {'the sensor count of config_check_hw is not m...
# 4                   {'check dut connections failed': 1}
# ...                                                 ...
# 5482           {'test-completion-missing-error-sat': 1}
# 5483               {'dimm infos validation failure': 1}
# 5484               {'dimm infos validation failure': 1}
# 5485               {'dimm infos validation failure': 1}
# 5486                   {'update google bios failed': 1}
#
#                                     label_message_cycle  \
# 0     {('ncsi_cable-preparation-error', 'failed to d...
# 1     {('ncsi_cable-preparation-error', 'failed to d...
# 2     {('ncsi_cable-preparation-error', 'failed to d...
# 3     {('the sensor count of config_check_hw is not ...
# 4     {('check dut connections failed', 'check sympt...
# ...                                                 ...
# 5482  {('test-completion-missing-error-sat', 'diag e...
# 5483  {('dimm infos validation failure', 'component ...
# 5484  {('dimm infos validation failure', 'component ...
# 5485  {('dimm infos validation failure', 'component ...
# 5486  {('update google bios failed', 'update bios fa...
#
#                                                Category  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4                                                    {}
# ...                                                 ...
# 5482                                                 {}
# 5483  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...
# 5484  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...
# 5485  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...
# 5486                                                 {}
#
#                                              Suggestion Label_Cycle_Count  \
# 0                                                    {}                 1
# 1                                                    {}                 1
# 2                                                    {}                 1
# 3                                                    {}                 1
# 4                                                    {}                 1
# ...                                                 ...               ...
# 5482                                                 {}                 1
# 5483  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...                 1
# 5484  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...                 1
# 5485  {'component dimm sn: (l)64gb 2rx4 pc5-4800b-ra...                 1
# 5486                                                 {}                 1
#
#       Message_Cycle_Count
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 5482                    1
# 5483                    1
# 5484                    1
# 5485                    1
# 5486                    1
#
# [5000 rows x 21 columns]

# %%
# cases that exactly match with debug tree
singel_label_message_match_message = singel_label_message_debug_result[singel_label_message_debug_result['Message_Cycle_Count'] != 'N/A']
singel_label_message_match_message["Category"] = singel_label_message_match_message["Category"].apply(
    lambda x: next(iter(x.values())) if isinstance(x,   dict) and len(x) == 1 else list(x.values()) if isinstance(x, dict) else x
)
singel_label_message_match_message["Suggestion"] = singel_label_message_match_message["Suggestion"].apply(
    lambda x: next(iter(x.values())) if isinstance(x, dict) and len(x) == 1 else list(x.values()) if isinstance(x, dict) else x
)

# Extract all unique labels
unique_label_match_label_message = set()

for label_dict in singel_label_message_match_message["label_cycle"]:
    if isinstance(label_dict, dict):
        unique_label_match_label_message.update(label_dict.keys())

# Extract all unique (label, message) pairs
unique_label_message_pairs_match_label_message = set()

for label_message_dict in singel_label_message_match_message["label_message_cycle"]:
    if isinstance(label_message_dict, dict):
        unique_label_message_pairs_match_label_message.update(label_message_dict.keys())

# Convert to a list if needed
unique_label_message_pairs_match_label_message = list(unique_label_message_pairs_match_label_message)
print(len(unique_label_message_pairs_match_label_message))

singel_label_message_match_message = singel_label_message_match_message.drop(columns=['label_cycle', 'label_message_cycle', 'Label_Cycle_Count'])
singel_label_message_match_message
# Out:
# 99
#       model_name build_type    skuno  serial_number              station  \
# 0        ASTORIA         GA  1154500  FWI2345-00007  AST Functional Test
# 1        ASTORIA         GA  1154500  FWI2345-00007  AST Functional Test
# 2        ASTORIA         GA  1154500  FWI2345-00007  AST Functional Test
# 15       ASTORIA         GA  1170765  FWI2348-00355  AST Functional Test
# 23       ASTORIA         GA  1158438  FWI2349-01033      AST Run-in Test
# ...          ...        ...      ...            ...                  ...
# 60164    ASTORIA         GA  1182051  FWI2511-09601  AST Functional Test
# 60166    ASTORIA         GA  1182051  FWI2511-09606  AST Functional Test
# 60168    ASTORIA         GA  1182051  FWI2511-09612      AST Run-in Test
# 60186    ASTORIA         GA  1182051  FWI2511-09658         AST Pre-Test
# 60187    ASTORIA         GA  1182051  FWI2511-09658         AST Pre-Test
#
#              repaired_date                                       symptom_info  \
# 0      2023-11-15 15:58:55  {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 1      2023-11-15 15:58:55  {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 2      2023-11-15 15:58:55  {'PassSymRunKey_be8307a8-0f5e-4466-b2f6-8c4396...
# 15     2023-11-30 09:45:52  {'SymptomRunKey_67a7ebab-3d5d-4953-94b9-73cb2a...
# 23     2023-12-06 13:43:47  {'SymptomRunKey_8a354d62-a1ab-4c96-ab17-4efdb9...
# ...                    ...                                                ...
# 60164  2025-03-14 12:23:49  {'SymptomRunKey_16db3090-d980-4eed-88f6-fe675a...
# 60166  2025-03-14 12:24:57  {'SymptomRunKey_223dbd1c-ea1f-44b2-94e8-2f569f...
# 60168  2025-03-14 19:29:44  {'SymptomRunKey_918eba67-7abe-407d-82d5-f915d8...
# 60186  2025-03-14 01:28:31  {'SymptomRunKey_59852e6d-6236-42ee-9fd8-542af6...
# 60187  2025-03-14 14:41:20  {'SymptomRunKey_7ea4d6cf-aee2-4073-bc26-8463fa...
#
#                                      failure_description     repair_code  \
# 0                           ncsi_cable-preparation-error   REPLACE- MOBO
# 1                           ncsi_cable-preparation-error    REPLACE- CPU
# 2                           ncsi_cable-preparation-error    REPLACE- CPU
# 15                     test-completion-missing-error-dna          RETEST
# 23               test-completion-missing-error-memtester      SWAP - CPU
# ...                                                  ...             ...
# 60164  Checking BMC boot readiness and get BMC IP Failed          RETEST
# 60166  Checking BMC boot readiness and get BMC IP Failed          RETEST
# 60168                  test-completion-missing-error-sat          RETEST
# 60186     Pre Diorite firmware check on all slots Failed          RETEST
# 60187     Pre Diorite firmware check on all slots Failed  RESEAT - AGORA
#
#                                     repaired_description  \
# 0      reseat ncsi; fail; replace ncsi; fail; reseat ...
# 1                             replace mobo; replace cpu1
# 2                             replace mobo; replace cpu0
# 15                           validating new diag 4.0.8.0
# 23     CPU0 CACHE, Error type: uncorrectable-cpu-erro...
# ...                                                  ...
# 60164                  unit not fully inserted into slot
# 60166                  unit not fully inserted into slot
# 60168                                             Retest
# 60186                                             retest
# 60187                                       reseat agora
#
#                                             symptom_dict  no_match_flag  \
# 0      {'ncsi_cable-preparation-error': ['failed to d...          False
# 1      {'ncsi_cable-preparation-error': ['failed to d...          False
# 2      {'ncsi_cable-preparation-error': ['failed to d...          False
# 15     {'test-completion-missing-error-dna': ['diag e...          False
# 23     {'test-completion-missing-error-memtester': ['...          False
# ...                                                  ...            ...
# 60164  {'checking bmc boot readiness and get bmc ip f...          False
# 60166  {'checking bmc boot readiness and get bmc ip f...          False
# 60168  {'test-completion-missing-error-sat': ['diag e...          False
# 60186  {'pre diorite firmware check on all slots fail...          False
# 60187  {'pre diorite firmware check on all slots fail...          False
#
#        empty_symptom_flag  empty_message_flag  isRepair      Category  \
# 0                   False               False      True  Quick Repair
# 1                   False               False      True   Slow Repair
# 2                   False               False      True      Debug II
# 15                  False               False      True        Retest
# 23                  False               False      True        Retest
# ...                   ...                 ...       ...           ...
# 60164               False               False      True        Retest
# 60166               False               False      True        Retest
# 60168               False               False      True        Retest
# 60186               False               False      True  Quick Repair
# 60187               False               False      True       Debug I
#
#                                               Suggestion Message_Cycle_Count
# 0      1. Verify proper seating for NCSI cable on bot...                   1
# 1      1. Verify previous repair action\n2. Replace N...                   2
# 2      1. Try golden NCSI cable\n2. Try golden NIC ca...                   3
# 15                                             1. Retest                   1
# 23                                             1. Retest                   1
# ...                                                  ...                 ...
# 60164                                          1. Retest                   1
# 60166                                          1. Retest                   1
# 60168                                          1. Retest                   1
# 60186                                    1. Reseat agora                   1
# 60187  1. Try golden agora\n2. Reseat PCIe cable for ...                   2
#
# [13542 rows x 18 columns]

# %%
hb16_patterns = [rf"device not found\.\s*can't validate pcie info for 'pe{pe}.io0'"for pe in range(2, 6)]
pcie_pelane_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'lane_error' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpulane_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'lane_error' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

pcie_pereceiver_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'receiver_error' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpureceiver_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'receiver_error' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

pcie_pereplay_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/pe{pe}/io\d+.*? pcie error, error types: 'replay_timer_timeout' are exceeding thresholds\."
    for pe in range(0, 8)  # ✅ Only `pe2` to `pe7`
]

pcie_cpureplay_patterns = [
    rf"^pcie serial number: .+?, location: [\w:.]+, devpath: /phys/cpu{cpu}.*? pcie error, error types: 'replay_timer_timeout' are exceeding thresholds\."
    for cpu in range(0, 2)  # ✅ Only `cpu0` and `cpu1`
]

sensor_fan_tach_patterns = [
    rf"^got \d+ violations, exceeding threshold of \d+ for sensor fan{fan} tach\."
    for fan in range(0, 6) 
]

match_criteria = {
    'memtester-insufficient-memory': "available memory: \d+, minimum required memory: \d+",
    "capture diorite console and attach to log failed":  r"^caught .*? exception",
    r"sata fio /dev/sda (read|write) bw too slow,? cur: \d+, exp: \d+": [r'(?s)(?=.*"fio version")(?=.*"timestamp")(?=.*"timestamp_ms")(?=.*"time")'],  # Message regex
    r"command execution failed: date": r"exception message", # Message regex
    "dimm infos validation failure": r"component dimm sn: .*? not found on unit",
    "hb16 pcie link speed and width check": hb16_patterns,
    "diorite location validation failure": [r"component diorite sn: .*? not found on unit",r"component diorite sn \S+ location: \S+, expected location: \S+"],
    "pcierrors-high-lane_error-rate": pcie_pelane_patterns + pcie_cpulane_patterns,
    "pcierrors-high-receiver_error-rate": pcie_pereceiver_patterns + pcie_cpureceiver_patterns,
    "pcierrors-high-replay_timer_timeout-rate": pcie_pereplay_patterns + pcie_cpureplay_patterns,
    "lower critical limit violated": sensor_fan_tach_patterns,
    "hb16 location validation failure": [r"component hb16 sn: .*? not found on unit",r"component hb16 sn \S+ location: \S+, expected location: \S+"],
    "error-monitor-procedural-error": r"^Test failed:.*?INTERNAL:",
    "diorite part number": r"value\s*=\s*['\"]([^'\"]+)['\"]\s*lower_limit\s*=\s*['\"]([^'\"]*)['\"]\s*upper_limit\s*=\s*['\"]([^'\"]*)['\"]",
    "send command fail:\s*stressapptest": "exception message:\s*\ntraceback",
    "diorite ssh connection failed": "create diorite ssh connection failed\.\s*can not connect to diorite ip: ",
    "cpu location validation failure": [r"component cpu sn: .*? not found on unit",r"component cpu sn \S+ location: \S+, expected location: \S+"],
    "timeout exceeded.": r"thread .*? execution exceeded the timeout limit of .*? seconds",
    "attach booting logs to otc failed": r"attach booting logs to otc failed.\nmsg:",
    "caught oserror exception.": r"traceback \(most recent call last\):\n.*",
    "dimm location validation failure": r"component dimm sn .+? location: .+?, expected location: .+?",
    "io adapter location validation failure": r"component io adapter sn .+? location: .+?, expected location: .+?",
    "gssd location validation failure": [r"component gssd sn: .*? not found on unit",r"component gssd sn \S+ location: \S+, expected location: \S+"],
    "cssd infos validation failure": r"component cssd sn: .*? not found on unit",
    "configuration check (hardware) failed": r"parse response failure. response:",
    "configuration check (software) failed": r"send command",
    "bad-bus": r"for local bus.*?/phys/cpu\d+.*?expected speed:.*?, actual speed:"
}

def single_label_message_debug_update_based_on_keyword(processed_result_df, debug_df, match_dict):
    processed_result_df_copy = processed_result_df.copy()

    # ✅ Step 1: Create `debug_dict = {label: {message: row_data}}` for fast lookup
    debug_dict = {}
    for _, row in debug_df.iterrows():
        debug_label = row["symptom_label"]
        debug_message = row["symptom_message"]
        debug_dict.setdefault(debug_label, {})[debug_message] = row  # Store full row for lookup

    # ✅ Step 2: Initialize tracking for label & message counts per serial_number
    serial_label_count = {}  # {serial_number: {label_pattern: count}}
    serial_label_message_count = {}  # {serial_number: {(label_pattern, message): count}}

    # ✅ Step 3: Iterate over `processed_result_df`
    for index, row in processed_result_df_copy.iterrows():
        serial_number = row["serial_number"]
        label_message_cycle = row["label_message_cycle"]  # Extract {(label, message): count}

        # Initialize tracking for this serial_number
        if serial_number not in serial_label_count:
            serial_label_count[serial_number] = {}
            serial_label_message_count[serial_number] = {}

        for (label, message), _ in label_message_cycle.items():
            matched_label = None

            # ✅ Step 4: Find matching label in `match_dict`
            for pattern_label in match_dict.keys():
                if re.fullmatch(pattern_label, label, re.IGNORECASE) or re.search(pattern_label, label, re.IGNORECASE):
                    matched_label = pattern_label
                    break  # Stop after first match

            if not matched_label:
                continue  # No match, skip

            # ✅ Step 5: Find previous occurrences using regex matching on `serial_label_count`
            previous_label_counts = [
                count for prev_label, count in serial_label_count[serial_number].items()
                if re.fullmatch(matched_label, prev_label, re.IGNORECASE) or re.search(matched_label, prev_label, re.IGNORECASE)
            ]
            label_count = max(previous_label_counts) + 1 if previous_label_counts else 1  # Ensure first occurrence is 1

            # ✅ Step 6: Track label-message cycle separately
            previous_message_counts = [
                count for (prev_label, prev_message), count in serial_label_message_count[serial_number].items()
                if (re.fullmatch(matched_label, prev_label, re.IGNORECASE) or re.search(matched_label, prev_label, re.IGNORECASE))
                   and prev_message == message  # Match message exactly
            ]
            message_count = max(previous_message_counts) + 1 if previous_message_counts else 1

            # ✅ Step 7: Store the updated counts
            serial_label_count[serial_number][label] = label_count
            serial_label_message_count[serial_number][(label, message)] = message_count

            # ✅ Step 8: Assign to DataFrame
            processed_result_df_copy.at[index, "Label_Cycle_Count"] = label_count
            processed_result_df_copy.at[index, "Message_Cycle_Count"] = message_count

    return processed_result_df_copy

# %%
new_singel_label_message_debug_result = single_label_message_debug_update_based_on_keyword(singel_label_message_debug_result, debug_df, match_criteria)
new_singel_label_message_debug_result["Category"] = new_singel_label_message_debug_result["Category"].apply(
    lambda x: next(iter(x.values())) if isinstance(x, dict) and len(x) == 1 else x
)


new_singel_label_message_debug_result["Suggestion"] = new_singel_label_message_debug_result["Suggestion"].apply(
    lambda x: next(iter(x.values())) if isinstance(x, dict) and len(x) == 1 else x
)

# %%
test = new_singel_label_message_debug_result[~
    new_singel_label_message_debug_result["Category"].apply(lambda x: isinstance(x, dict))
]
test2 = test[~test['Message_Cycle_Count'].isin([1,2,3])]
test2.iloc[3].label_message_cycle
# Out:
# {('test-completion-missing-error-cpu_functional', 'diag execution failed.'): 4}

# %%
aa = test[test['Label_Cycle_Count']=='N/A']
aa['Computed_Count'] = aa['label_cycle'].apply(lambda x: list(x.values())[0])
aa[aa['Computed_Count'] != aa['Message_Cycle_Count']].serial_number.unique()
# Out:
# array(['FWI2405-10924', 'FWI2406-06429', 'FWI2407-05930', 'FWI2414-13626',
#        'FWI2419-11518', 'FWI2430-00630', 'FWI2431-03279', 'FWI2433-11544',
#        'FWI2435-09442', 'FWI2443-04306', 'FWI2450-17222', 'FWI2451-01826',
#        'FWI2451-11137', 'FWI2501-26708', 'FWI2501-27922', 'FWI2501-28290',
#        'FWI2501-28420', 'FWI2501-28883', 'FWI2501-36411', 'FWI2501-38000',
#        'FWI2501-38368', 'FWI2502-01335', 'FWI2502-02264', 'FWI2502-02433',
#        'FWI2502-03748', 'FWI2502-07028', 'FWI2502-08090', 'FWI2502-08245',
#        'FWI2503-01227', 'FWI2503-01406', 'FWI2503-02217', 'FWI2503-14695',
#        'FWI2503-15864', 'FWI2503-18697', 'FWI2504-00035', 'FWI2504-10041',
#        'FWI2504-10477', 'FWI2504-14709', 'FWI2507-05135', 'FWI2507-14551',
#        'FWI2509-01307', 'FWI2509-18572', 'FWI2510-07567'], dtype=object)

# %%
def find_matching_rows(label_message_cycle, match_dict):
    if not isinstance(label_message_cycle, dict):  # Ensure it's a dictionary
        return False

    for (label, message) in label_message_cycle:  # ✅ No need for `.keys()`
        matched_label = None

        # **Step 1: Check if label has an exact or regex match**
        for pattern_label, pattern in match_dict.items():
            if re.fullmatch(pattern_label, label, re.IGNORECASE) or re.search(pattern_label, label, re.IGNORECASE):
                matched_label = pattern_label
                break  # Stop after the first match

        if matched_label:
            regex_patterns = match_dict[matched_label]

            # ✅ Ensure `regex_patterns` is a list (handles both single and multiple regex cases)
            if not isinstance(regex_patterns, list):
                regex_patterns = [regex_patterns]

            # **Step 2: Clean and Match Message**
            cleaned_message = re.sub(r"\s+", " ", message).strip()

            for regex_pattern in regex_patterns:
                if re.search(regex_pattern, cleaned_message, re.IGNORECASE | re.DOTALL):
                    return True  # ✅ Found a match

    return False  # ❌ No match

match_criteria = {
    "diorite location validation failure": [r"component diorite sn: .*? not found on unit",r"component diorite sn \S+ location: \S+, expected location: \S+"],}

find = new_singel_label_message_debug_result[
    new_singel_label_message_debug_result["label_message_cycle"].apply(lambda x: find_matching_rows(x, match_criteria))
]

find
# find2 = find[find["Category"].apply(lambda x: isinstance(x, dict))]
# print(len(find2["label_message_cycle"].apply(lambda x: list(x.keys())[0][1])))
# for i in find2["label_message_cycle"].apply(lambda x: list(x.keys())[0][1])[:10]:
#     print(f'"{i}",')  # ✅ Correct way to print
# Out:
#        model_name build_type    skuno  serial_number       station  \
# 4522      ASTORIA        PVT  1182051  FWI2408-02238  AST Pre-Test
# 4524      ASTORIA        PVT  1182051  FWI2408-02239  AST Pre-Test
# 4556      ASTORIA        PVT  1182051  FWI2408-02264  AST Pre-Test
# 4575      ASTORIA        PVT  1182051  FWI2408-02274  AST Pre-Test
# 4607      ASTORIA        PVT  1182051  FWI2408-02289  AST Pre-Test
# ...           ...        ...      ...            ...           ...
# 111926    ASTORIA         GA  1182051  FWI2509-15167  AST Pre-Test
# 111931    ASTORIA         GA  1182051  FWI2509-15204  AST Pre-Test
# 111945    ASTORIA         GA  1182051  FWI2509-15239  AST Pre-Test
# 112058    ASTORIA         GA  1182051  FWI2509-15738  AST Pre-Test
# 112094    ASTORIA         GA  1182051  FWI2509-15853  AST Pre-Test
#
#               repaired_date   repair_code  \
# 4522    2024-02-23 19:15:23    SWAP - NIC
# 4524    2024-02-24 11:10:45    SWAP - NIC
# 4556    2024-02-24 08:05:00    SWAP - NIC
# 4575    2024-02-23 12:02:50    SWAP - NIC
# 4607    2024-02-24 09:04:08    SWAP - NIC
# ...                     ...           ...
# 111926  2025-03-03 13:37:28  REPLACE- NIC
# 111931  2025-02-28 23:26:14  RESEAT - NIC
# 111945  2025-03-03 13:36:38  REPLACE- NIC
# 112058  2025-03-04 10:35:34  REPLACE- NIC
# 112094  2025-03-03 11:44:19  REPLACE- NIC
#
#                                      repaired_description  \
# 4522                  Swap NIC card in system, PE0 to PE1
# 4524    Swap NIC card in system, installed in wrong lo...
# 4556    Swap NIC card in system, installed in wrong lo...
# 4575                  Swap NIC card in system, PE0 to PE1
# 4607    Swap NIC card in system, installed in wrong lo...
# ...                                                   ...
# 111926  PE1 IO0 not detected - swap PE1 and PE0 nic ca...
# 111931                   Reseated Nic card and PCIe cable
# 111945  PE7 IO0 not detected - swap PE7 and PE6 nic ca...
# 112058  PE7 IO0 not detected - swap PE7 and PE6 nic ca...
# 112094  FWI2509-15853\tPE1 nic card not found on unit;...
#
#                                              symptom_dict  \
# 4522    {'diorite location validation failure': ['comp...
# 4524    {'diorite location validation failure': ['comp...
# 4556    {'diorite location validation failure': ['comp...
# 4575    {'diorite location validation failure': ['comp...
# 4607    {'diorite location validation failure': ['comp...
# ...                                                   ...
# 111926  {'diorite location validation failure': ['comp...
# 111931  {'diorite location validation failure': ['comp...
# 111945  {'diorite location validation failure': ['comp...
# 112058  {'diorite location validation failure': ['comp...
# 112094  {'diorite location validation failure': ['comp...
#
#                                        label_cycle  \
# 4522    {'diorite location validation failure': 1}
# 4524    {'diorite location validation failure': 1}
# 4556    {'diorite location validation failure': 1}
# 4575    {'diorite location validation failure': 1}
# 4607    {'diorite location validation failure': 1}
# ...                                            ...
# 111926  {'diorite location validation failure': 1}
# 111931  {'diorite location validation failure': 1}
# 111945  {'diorite location validation failure': 1}
# 112058  {'diorite location validation failure': 1}
# 112094  {'diorite location validation failure': 1}
#
#                                       label_message_cycle      Category  \
# 4522    {('diorite location validation failure', 'comp...  Quick Repair
# 4524    {('diorite location validation failure', 'comp...  Quick Repair
# 4556    {('diorite location validation failure', 'comp...  Quick Repair
# 4575    {('diorite location validation failure', 'comp...  Quick Repair
# 4607    {('diorite location validation failure', 'comp...  Quick Repair
# ...                                                   ...           ...
# 111926  {('diorite location validation failure', 'comp...  Quick Repair
# 111931  {('diorite location validation failure', 'comp...  Quick Repair
# 111945  {('diorite location validation failure', 'comp...  Quick Repair
# 112058  {('diorite location validation failure', 'comp...  Quick Repair
# 112094  {('diorite location validation failure', 'comp...  Quick Repair
#
#                                                Suggestion Label_Cycle_Count  \
# 4522                         1. Swap PE# to PE## NIC card                 1
# 4524                         1. Swap PE# to PE## NIC card                 1
# 4556                         1. Swap PE# to PE## NIC card                 1
# 4575                         1. Swap PE# to PE## NIC card                 1
# 4607                         1. Swap PE# to PE## NIC card                 1
# ...                                                   ...               ...
# 111926  1. Verify PCIe cable for proper seating, verif...                 1
# 111931  1. Verify PCIe cable for proper seating, verif...                 1
# 111945  1. Verify PCIe cable for proper seating, verif...                 1
# 112058  1. Verify PCIe cable for proper seating, verif...                 1
# 112094  1. Verify PCIe cable for proper seating, verif...                 1
#
#        Message_Cycle_Count
# 4522                     1
# 4524                     1
# 4556                     1
# 4575                     1
# 4607                     1
# ...                    ...
# 111926                   1
# 111931                   1
# 111945                   1
# 112058                   1
# 112094                   1
#
# [3186 rows x 15 columns]

# %%
# Step 1: Filter rows where Category is a dictionary (non-empty or empty)
filtered_df = new_singel_label_message_debug_result[
    new_singel_label_message_debug_result["Category"].apply(lambda x: isinstance(x, dict))
]
# Step 2: Extract unique (label, message) pairs from label_message_cycle
unique_label_message_pairs_match_label = set()

for label_message_dict in filtered_df["label_message_cycle"]:
    if isinstance(label_message_dict, dict):
        unique_label_message_pairs_match_label.update(label_message_dict.keys())  # Extract (label, message) pairs

# Extract all unique labels from label_cycle
unique_labels_match_label = set()

for label_dict in filtered_df["label_cycle"]:
    if isinstance(label_dict, dict):
        unique_labels_match_label.update(label_dict.keys())

print('Rest of the lable-message need classified amount: ', len(list(unique_label_message_pairs_match_label)))
# Out:
# Rest of the lable-message need classified amount:  3038

# %%
# Step 1: Get the labels that match from debug_df
need_match_labels = list(set(debug_df["symptom_label"]).intersection(unique_labels_match_label))
print('Rest of the lable need classified amount: ', len(need_match_labels))
# Step 2: Create a dictionary to store unique message counts per label
label_message_count = {}

# Dictionary to store unique messages per label
label_unique_messages = {}

for label in need_match_labels:
    # Filter rows where `label` exists in `label_cycle`
    result = filtered_df[
        filtered_df["label_cycle"].apply(lambda x: any(label in label_key for label_key in x.keys()))
    ]

    # Collect unique messages for the label
    unique_messages = set()
    for label_message_dict in result["label_message_cycle"]:
        if isinstance(label_message_dict, dict):
            unique_messages.update(k[1] for k in label_message_dict.keys())  # Extract message part of (label, message)
    
    # Store the count of unique messages
    label_message_count[label] = len(unique_messages)
    label_unique_messages[label] = unique_messages  # Store the unique messages per label

# Step 3: Sort labels by the number of unique messages (descending)
sorted_labels = sorted(label_message_count.items(), key=lambda x: x[1], reverse=True)

# Step 5: Extract only the sorted label list
sorted_label_list = [label for label, _ in sorted_labels]

# ✅ Now, `sorted_label_list[0]` is the label with the most unique messages
top_label = sorted_label_list[0] if sorted_label_list else None
print(top_label)
# Step 6: If we have a top label, print its corresponding messages
if top_label:
    top_label_messages = label_unique_messages[top_label]  # Retrieve unique messages for the top label
    print(len(top_label_messages)) 
    for msg in top_label_messages:
        print(f"- {msg}")  # Print each message
# Out:
# Rest of the lable need classified amount:  51
# fru infos validation failure
# 1816
# - component sn: kw049419-96402 41608663 not found on unit
# - component fru sn: 2468056-1 24510a3pc not found on unit
# - component fru sn: 2468056-1 241414513 not found on unit
# - component fru sn: 2411266-1 234411132 not found on unit
# - component fru sn: 2468056-1 241716300 not found on unit
# - component sn: ipbfwi243703626 not found on unit
# - component fru sn: 2468056-1 245200dug not found on unit
# - component fru sn: 2411266-1 234408454 not found on unit
# - component fru sn: 2468056-1 244634666 not found on unit
# - component fru sn: 2468056-1 250130bgr not found on unit
# - component fru sn: 2468056-1 24510b30r not found on unit
# - component sn: ipbfwi250501834 not found on unit
# - component sn: pdfqmb243200504 not found on unit
# - component sn: habqtw244806810 not found on unit
# - component fru sn: 2468056-1 242070501 not found on unit
# - component fru sn: 2468056-1 250330a8m not found on unit
# - component fru sn: 2409682-1 230666486 not found on unit
# - component fru sn: lz6pe005-sd-r 244945260 not found on unit
# - component sn: ipbfwi240400485 not found on unit
# - component sn: kw049419-96402 50213885 not found on unit
# - component fru sn: 2409682-1 223105319 not found on unit
# - component sn: ipbfwi240700929 not found on unit
# - component fru sn: 2468056-1 245200e2h not found on unit
# - component fru sn: 2468056-1 245200e29 not found on unit
# - component sn: kw049419-96402 41714941 not found on unit
# - component fru sn: 2468056-1 250200y7t not found on unit
# - component fru sn: 2468056-1 244517192 not found on unit
# - component fru sn: rc164-2293 245106048 not found on unit
# - component fru sn: lz6pe005-sd-r 244607224 not found on unit
# - component sn: ipbfwi244503989 not found on unit
# - component fru sn: 2409682-1 224772414 not found on unit
# - component fru sn: 2468056-1 245201frm not found on unit
# - component fru sn: rc164-2293 245114993 not found on unit
# - component fru sn: 2468056-1 24510a3lp not found on unit
# - component fru sn: 2468056-1 244403213 not found on unit
# - component fru sn: astfwi244203804 not found on unit
# - component fru sn: 2411266-1 234420387 not found on unit
# - component fru sn: rc164-2293 244316577 not found on unit
# - component fru sn: 2468056-1 244627060 not found on unit
# - component fru sn: 2468056-1 244803413 not found on unit
# - component sn: pdfqmb243107171 not found on unit
# - component fru sn: 2409682-1 224977817 not found on unit
# - component sn: pdfcth241407110 not found on unit
# - component fru sn: lz6pe005-sd-r 244717997 not found on unit
# - component sn: ipbfwi250111749 not found on unit
# - component fru sn: 2468056-1 244633248 not found on unit
# - component fru sn: 2468056-1 244813668 not found on unit
# - component fru sn: 2468056-1 2452008c6 not found on unit
# - component fru sn: astfwi245000036 not found on unit
# - component fru sn: aahfwi241400655 not found on unit
# - component fru sn: 2468056-1 2452018vm not found on unit
# - component fru sn: 2468056-1 244526827 not found on unit
# - component sn: habqtw250216585 not found on unit
# - component sn: kw049419-96402 41708366 not found on unit
# - component fru sn: 2468056-1 24510b3f9 not found on unit
# - component fru sn: astivt243401339 not found on unit
# - component fru sn: 2468056-1 245200f9v not found on unit
# - component fru sn: 2468056-1 244833106 not found on unit
# - component sn: pdfqmb244404714 not found on unit
# - component fru sn: lz6pe005-sd-r 244810016 not found on unit
# - component fru sn: 2468056-1 250300y2a not found on unit
# - component sn: pdfcth243021575 not found on unit
# - component fru sn: 2468056-1 244766353 not found on unit
# - component fru sn: 2468056-1 245201ekm not found on unit
# - component fru sn: 2468056-1 244707494 not found on unit
# - component fru sn: astivt244201365 not found on unit
# - component fru sn: 2468056-1 244658749 not found on unit
# - component fru sn: 2468056-1 2452003e2 not found on unit
# - component sn: ipbfwi243703963 not found on unit
# - component sn: kw049419-96402 41707389 not found on unit
# - component sn: pdfqmb244407990 not found on unit
# - component sn: ipbfwi244200027 not found on unit
# - component fru sn: lz6pe005-sd-r 244920525 not found on unit
# - component sn: pdfcth244812350 not found on unit
# - component sn: ipbfwi240100384 not found on unit
# - component sn: kw049419-96402 41719220 not found on unit
# - component fru sn: astfwi245000052 not found on unit
# - component fru sn: 2468056-1 250202kav not found on unit
# - component fru sn: astfwi234003442 not found on unit
# - component fru sn: 2468056-1 244991534 not found on unit
# - component fru sn: rc164-2293 245111860 not found on unit
# - component fru sn: 2468056-1 24510b51b not found on unit
# - component fru sn: 2468056-1 244944240 not found on unit
# - component fru sn: astfwi245000288 not found on unit
# - component fru sn: 2468056-1 243191807 not found on unit
# - component pn: 1123888-03 not match unit pn: 1131563-02
# - component sn: pdfqmb243002752 not found on unit
# - component fru sn: 2468056-1 243876274 not found on unit
# - component fru sn: lz6pe005-sd-r 244712137 not found on unit
# - component sn: pdfcth243100052 not found on unit
# - component fru sn: 2468056-1 242069319 not found on unit
# - component sn: ipbfwi240401081 not found on unit
# - component sn: ipbfwi240500848 not found on unit
# - component sn: kw049419-96402 40420688 not found on unit
# - component fru sn: 2468056-1 245049138 not found on unit
# - component sn: ipbfwi243005715 not found on unit
# - component fru sn: 2468056-1 24510bjdc not found on unit
# - component fru sn: aahfwi244404435 not found on unit
# - component fru sn: 2468056-1 244906900 not found on unit
# - component fru sn: 2468056-1 250101w22 not found on unit
# - component fru sn: rc164-2293 244303020 not found on unit
# - component fru sn: 2468056-1 24510bal6 not found on unit
# - component sn: pdfqmb243501844 not found on unit
# - component sn: kw049419-96402 35110952 not found on unit
# - component sn: ipbfwi243005098 not found on unit
# - component fru sn: 2468056-1 241442970 not found on unit
# - component fru sn: 2468056-1 242750322 not found on unit
# - component fru sn: astfwi242901505 not found on unit
# - component fru sn: 2468056-1 2501300ty not found on unit
# - component fru sn: 2468056-1 245200ptj not found on unit
# - component fru sn: 2468056-1 244939285 not found on unit
# - component fru sn: 2468056-1 24510au39 not found on unit
# - component sn: habqtw245016585 not found on unit
# - component fru sn: lz6pe005-sd-r 244966810 not found on unit
# - component fru sn: astfwi245000204 not found on unit
# - component sn: pdfcth244915381 not found on unit
# - component fru sn: astivt244502516 not found on unit
# - component fru sn: lz6pe005-sd-r 244969638 not found on unit
# - component sn: kw049419-96402 42516126 not found on unit
# - component fru sn: 2468056-1 245023696 not found on unit
# - component fru sn: lz6pe005-sd-r 244947738 not found on unit
# - component sn: ipbfwi243703494 not found on unit
# - component fru sn: 2409682-1 224061050 not found on unit
# - component fru sn: 2468056-1 24510a471 not found on unit
# - component sn: habqtw245214246 not found on unit
# - component fru sn: 2468056-1 24510a1ub not found on unit
# - component fru sn: lz6pe005-sd-r 244516928 not found on unit
# - component sn: habqtw244110876 not found on unit
# - component fru sn: astfwi245000193 not found on unit
# - component sn: kw049419-96402 41706031 not found on unit
# - component fru sn: astivt243301970 not found on unit
# - component fru sn: aahivt244901335 not found on unit
# - component fru sn: 2468056-1 245126616 not found on unit
# - component fru sn: 2468056-1 24510b9md not found on unit
# - component fru sn: 2468056-1 244717617 not found on unit
# - component sn: ipbfwi235100961 not found on unit
# - component fru sn: lz6pe005-sd-r 244930333 not found on unit
# - component sn: ipbfwi234801006 not found on unit
# - component fru sn: 2468056-1 24510aha1 not found on unit
# - component fru sn: 2468056-1 2503007cj not found on unit
# - component fru sn: aahivt241501242 not found on unit
# - component fru sn: 2468056-1 2503309ny not found on unit
# - component fru sn: 2468056-1 2452017r7 not found on unit
# - component fru sn: lz6pe005-sd-r 244405076 not found on unit
# - component fru sn: 2409682-1 224977480 not found on unit
# - component fru sn: astfwi245200115 not found on unit
# - component fru sn: rc164-2293 244901071  not found on unit
# - component fru sn: astivt242802324 not found on unit
# - component fru sn: 2411266-1 241308634 not found on unit
# - component sn: ipbfwi240901349 not found on unit
# - component sn: ipbfwi240700138 not found on unit
# - component fru sn: lz6pe005-sd-r 244924215 not found on unit
# - component fru sn: 2468056-1 24510av14 not found on unit
# - component sn: ipbfwi243001217 not found on unit
# - component fru sn: aahfwi250406355 not found on unit
# - component fru sn: astfwi250200092 not found on unit
# - component fru sn: 2468056-1 2503007cb not found on unit
# - component fru sn: astfwi250606012 not found on unit
# - component fru sn: 2468056-1 244942437 not found on unit
# - component fru sn: 2468056-1 245200yjy not found on unit
# - component fru sn: astfwi245000283 not found on unit
# - component fru sn: 2126700804 244720252 not found on unit
# - component fru sn: lz6pe005-sd-r 244815617 not found on unit
# - component fru sn: 2468056-1 244631266 not found on unit
# - component sn: pdfcth241405810 not found on unit
# - component fru sn: 2468056-1 24510a2wd not found on unit
# - component fru sn: 2468056-1 24510awen not found on unit
# - component fru sn: astfwi245000054 not found on unit
# - component sn: kw049419-96402 41707749 not found on unit
# - component fru sn: lz6pe005-sd-r 244809686 not found on unit
# - component fru sn: astfwi240902065 not found on unit
# - component sn: ipbfwi243701706 not found on unit
# - component fru sn: 2468056-1 244664773 not found on unit
# - component fru sn: 2468056-1 2503303ly not found on unit
# - component fru sn: 2411266-1 234414436 not found on unit
# - component fru sn: aahivt243603777 not found on unit
# - component sn: pdfcth244907881 not found on unit
# - component fru sn: 2468056-1 243590778 not found on unit
# - component fru sn: astfwi245000351 not found on unit
# - component fru sn: 2468056-1 245113390 not found on unit
# - component sn: kw049419-96402 41707634 not found on unit
# - component sn: ipbfwi242105893 not found on unit
# - component sn: ipbfwi244802716 not found on unit
# - component sn: habqtw243905138 not found on unit
# - component fru sn: 2126700804 244621154 not found on unit
# - component sn: pdfqmb244104365 not found on unit
# - component fru sn: 2468056-1 250300r6m not found on unit
# - component fru sn: 2468056-1 242069878 not found on unit
# - component sn: pdfcth250312836 not found on unit
# - component sn: habqtw245026790 not found on unit
# - component fru sn: 2468056-1 242069790 not found on unit
# - component fru sn: aahivt244802615 not found on unit
# - component fru sn: aahfwi241601260 not found on unit
# - component sn: kw049419-96402 42514069 not found on unit
# - component sn: kw049419-96402 42413890 not found on unit
# - component fru sn: 2468056-1 244600119 not found on unit
# - component fru sn: 2468056-1 250100jyb not found on unit
# - component fru sn: 2409682-1 223960769 not found on unit
# - component fru sn: 2468056-1 2452017l9 not found on unit
# - component fru sn: 2468056-1 245201ldu not found on unit
# - component sn: ipbfwi250204260 not found on unit
# - component fru sn: 2468056-1 245201ggt not found on unit
# - component fru sn: astivt244202310 not found on unit
# - component fru sn: 2468056-1 245200edw not found on unit
# - component fru sn: 2468056-1 243484282 not found on unit
# - component fru sn: aahfwi241603790 not found on unit
# - component sn: ipbfwi250308044 not found on unit
# - component fru sn: 2468056-1 24510b5j6 not found on unit
# - component sn: habqtw245025070 not found on unit
# - component fru sn: 2468056-1 24510a9wl not found on unit
# - component fru sn: 2468056-1 250201jwf not found on unit
# - component sn: kw049419-96402 41615371 not found on unit
# - component sn: ipbfwi240801330 not found on unit
# - component fru sn: 2468056-1 245000026 not found on unit
# - component fru sn: 2468056-1 245200bt6 not found on unit
# - component sn: ipbfwi250800496 not found on unit
# - component sn: pdfqmb244400966 not found on unit
# - component fru sn: 2468056-1 244906769 not found on unit
# - component sn: kw049419-96402 42514160 not found on unit
# - component sn: kw049419-96402 43204574 not found on unit
# - component fru sn: 2409682-1 225080255 not found on unit
# - component fru sn: 2468056-1 2452010hy not found on unit
# - component fru sn: lz6pe005-sd-r 244808465 not found on unit
# - component fru sn: 2468056-1 244526762 not found on unit
# - component fru sn: aahivt244100677 not found on unit
# - component fru sn: 2409682-1 222500436 not found on unit
# - component sn: ipbfwi250208584 not found on unit
# - component sn: kw049419-96402 43205488 not found on unit
# - component fru sn: 2468056-1 244533379 not found on unit
# - component sn: habqtw245141163 not found on unit
# - component fru sn: 2468056-1 2452016nh not found on unit
# - component sn: ipbfwi244503773 not found on unit
# - component fru sn: 2468056-1 250202hfc not found on unit
# - component fru sn: 2468056-1 2503307u4 not found on unit
# - component fru sn: aahfwi243400033 not found on unit
# - component fru sn: astfwi245000165 not found on unit
# - component fru sn: astivt244501502 not found on unit
# - component fru sn: 2468056-1 24510awu0 not found on unit
# - component fru sn: lz6pe005-sd-r 244811053 not found on unit
# - component fru sn: 2468056-1 244714757 not found on unit
# - component sn: ipbfwi235101139 not found on unit
# - component fru sn: 2468056-1 24520154y not found on unit
# - component fru sn: 2468056-1 245023644 not found on unit
# - component fru sn: 2468056-1 244614959 not found on unit
# - component sn: kw049419-96402 41609904 not found on unit
# - component fru sn: 2468056-1 244717012 not found on unit
# - component fru sn: 2468056-1 244701200 not found on unit
# - component sn: ipbfwi235101605 not found on unit
# - component sn: ipbfwi250403493 not found on unit
# - component fru sn: lz6pe005-sd-r 244916925 not found on unit
# - component sn: ipbfwi235000884 not found on unit
# - component fru sn: 2468056-1 245200cfy not found on unit
# - component fru sn: 2411266-1 240428998 not found on unit
# - component fru sn: 2468056-1 245010123 not found on unit
# - component sn: habqtw245202612 not found on unit
# - component sn: ipbfwi245106180 not found on unit
# - component fru sn: 2468056-1 2452020m4 not found on unit
# - component fru sn: 2468056-1 24510akvh not found on unit
# - component fru sn: 2468056-1 245013685 not found on unit
# - component fru sn: 2468056-1 244658952 not found on unit
# - component sn: habqtw245136946 not found on unit
# - component fru sn: 2468056-1 24510ap9k not found on unit
# - component fru sn: astivt243801884 not found on unit
# - component fru sn: 2468056-1 24510ag0y not found on unit
# - component sn: habqtw245200530 not found on unit
# - component sn: habqtw245025707 not found on unit
# - component fru sn: aahivt244803494 not found on unit
# - component sn: kw049419-96402 41615493 not found on unit
# - component fru sn: rc164-2293 244206339 not found on unit
# - component sn: ipbfwi250210396 not found on unit
# - component fru sn: 2126700804 244621949 not found on unit
# - component fru sn: 2468056-1 24510bb7m not found on unit
# - component sn: kw049419-96402 42413732 not found on unit
# - component fru sn: 2468056-1 243598722 not found on unit
# - component fru sn: 2468056-1 245013980 not found on unit
# - component sn: ipbfwi240800263 not found on unit
# - component fru sn: 2468056-1 24510addw not found on unit
# - component fru sn: rc164-2293 244807242 not found on unit
# - component fru sn: aahfwi241301951 not found on unit
# - component fru sn: 2409682-1 230877569 not found on unit
# - component sn: ipbfwi243700039 not found on unit
# - component fru sn: 2468056-1 244887791 not found on unit
# - component fru sn: lz6pe005-sd-r 244628133 not found on unit
# - component fru sn: 2468056-1 244924268 not found on unit
# - component fru sn: lz6pe005-sd-r 244529938 not found on unit
# - component fru sn: rc164-2293 245107560 not found on unit
# - component fru sn: 2468056-1 2503001f7 not found on unit
# - component fru sn: 2468056-1 244945421 not found on unit
# - component sn: kw049419-96402 43521665 not found on unit
# - component fru sn: 2468056-1 245108065 not found on unit
# - component sn: kw049419-96402 41718520 not found on unit
# - component fru sn: 2468056-1 244659180 not found on unit
# - component fru sn: 2468056-1 245200ch6 not found on unit
# - component sn: pdfqmb243002735 not found on unit
# - component fru sn: 2409682-1 223960414 not found on unit
# - component fru sn: 2468056-1 24510bb7g not found on unit
# - component fru sn: astfwi244504636 not found on unit
# - component fru sn: astfwi245000428 not found on unit
# - component fru sn: 2468056-1 250200khl not found on unit
# - component fru sn: 2468056-1 244950217 not found on unit
# - component sn: kw049419-96402 41707832 not found on unit
# - component fru sn: 2468056-1 245201l65 not found on unit
# - component fru sn: lz6pe005-sd-r 244903718 not found on unit
# - component fru sn: 2468056-1 24510a27p not found on unit
# - component fru sn: 2468056-1 245201hry not found on unit
# - component fru sn: 2468056-1 2452020r5 not found on unit
# - component sn: ipbfwi242402577 not found on unit
# - component fru sn: 2468056-1 242069544 not found on unit
# - component sn: ipbfwi250206911 not found on unit
# - component sn: pdfcth224104388 not found on unit
# - component sn: ipbfwi240700040 not found on unit
# - component fru sn: lz6pe005-sd-r 244402384 not found on unit
# - component fru sn: astfwi242901527 not found on unit
# - component fru sn: 2411266-1 240438302 not found on unit
# - component fru sn: 2468056-1 241826424 not found on unit
# - component fru sn: lz6pe005-sd-r 244737834 not found on unit
# - component sn: habqtw250221869 not found on unit
# - component sn: pdfcth242716811 not found on unit
# - component fru sn: rc164-2293 245101062 not found on unit
# - component fru sn: lz6pe005-sd-r 244913097 not found on unit
# - component fru sn: 2468056-1 24510b47k not found on unit
# - component fru sn: rc164-2293 245113856 not found on unit
# - component fru sn: astfwi245000074 not found on unit
# - component fru sn: 2468056-1 244504444 not found on unit
# - component fru sn: 2468056-1 244522632 not found on unit
# - component fru sn: 2411266-1 234410689 not found on unit
# - component fru sn: 2126700804 244720041 not found on unit
# - component fru sn: lz6pe005-sd-r 244809861 not found on unit
# - component fru sn: 2468056-1 244430055 not found on unit
# - component sn: kw049419-96402 40414181 not found on unit
# - component fru sn: 2468056-1 244804059 not found on unit
# - component fru sn: 2468056-1 25033041e not found on unit
# - component fru sn: 2468056-1 24510ata9 not found on unit
# - component sn: kw049419-96402 43204267 not found on unit
# - component fru sn: 2468056-1 243655086 not found on unit
# - component fru sn: 2468056-1 24520182p not found on unit
# - component fru sn: 2468056-1 245200cve not found on unit
# - component fru sn: 2409682-1 224772270 not found on unit
# - component sn: ipbfwi224500598 not found on unit
# - component fru sn: lz6pe005-sd-r 244903537 not found on unit
# - component sn: pdfcth241902671 not found on unit
# - component fru sn: astfwi245000120 not found on unit
# - component sn: ipbfwi242202026 not found on unit
# - component fru sn: 2409682-1 224875297 not found on unit
# - component fru sn: 2468056-1 245028834 not found on unit
# - component fru sn: 2468056-1 245201dbm not found on unit
# - component fru sn: 2468056-1 245200d5d not found on unit
# - component sn: ipbfwi243703597 not found on unit
# - component fru sn: 2409682-1 224772273 not found on unit
# - component sn: habqtw244200542 not found on unit
# - component fru sn: 2468056-1 245201d2m not found on unit
# - component fru sn: aahfwi250402620 not found on unit
# - component fru sn: astfwi245000062 not found on unit
# - component sn: ipbfwi240800228 not found on unit
# - component fru sn: 2468056-1 245201d39 not found on unit
# - component sn: kw049419-96402 42514068 not found on unit
# - component fru sn: 2411266-1 234428819 not found on unit
# - component fru sn: 2468056-1 24510baku not found on unit
# - component fru sn: 2468056-1 244637423 not found on unit
# - component sn: ipbfwi240500776 not found on unit
# - component sn: kw049419-96402 43101282 not found on unit
# - component fru sn: aahivt244804026 not found on unit
# - component fru sn: 2468056-1 2452007f8 not found on unit
# - component fru sn: 2126700804 244622869 not found on unit
# - component fru sn: 2468056-1 24510b2f7 not found on unit
# - component sn: kw049419-96402 41612315 not found on unit
# - component fru sn: 2468056-1 242069789 not found on unit
# - component fru sn: astfwi245000277 not found on unit
# - component fru sn: astfwi245000461 not found on unit
# - component fru sn: 2468056-1 244608370 not found on unit
# - component fru sn: 2468056-1 24510ba70 not found on unit
# - component fru sn: rc164-2293 245107449 not found on unit
# - component fru sn: 2409682-1 224061452 not found on unit
# - component sn: habqtw243914274 not found on unit
# - component sn: habqtw245125511 not found on unit
# - component sn: ipbfwi243803006 not found on unit
# - component sn: ipbfwi250503757 not found on unit
# - component fru sn: 2468056-1 2452023kk not found on unit
# - component fru sn: 2468056-1 250300puw not found on unit
# - component sn: habqtw245010646 not found on unit
# - component fru sn: astfwi244502201 not found on unit
# - component sn: ipbfwi243003249 not found on unit
# - component fru sn: 2468056-1 244704706 not found on unit
# - component fru sn: 2468056-1 241716311 not found on unit
# - component fru sn: 2126700804 244720002 not found on unit
# - component fru sn: 2468056-1 244634511 not found on unit
# - component sn: kw049419-96402 41612324 not found on unit
# - component sn: ipbfwi240200515 not found on unit
# - component fru sn: 2468056-1 241717381 not found on unit
# - component fru sn: 2409682-1 230666536 not found on unit
# - component fru sn: 2468056-1 245200cmp not found on unit
# - component fru sn: 2468056-1 24510aw50 not found on unit
# - component fru sn: 2468056-1 24510avvb not found on unit
# - component fru sn: 2468056-1 242069911 not found on unit
# - component fru sn: 2468056-1 2502302e7 not found on unit
# - component sn: kw049419-96402 42414365 not found on unit
# - component sn: habqtw250207044 not found on unit
# - component fru sn: 2468056-1 244927367 not found on unit
# - component fru sn: 2468056-1 244888742 not found on unit
# - component fru sn: astivt244600355 not found on unit
# - component fru sn: 2468056-1 244526756 not found on unit
# - component fru sn: 2468056-1 245201d9n not found on unit
# - component fru sn: lz6pe005-sd-r 244630128 not found on unit
# - component fru sn: 2468056-1 245129028 not found on unit
# - component sn: pdfqmb244408177 not found on unit
# - component fru sn: rc164-2293 245114140 not found on unit
# - component fru sn: 2468056-1 242354247 not found on unit
# - component fru sn: astfwi245000114 not found on unit
# - component fru sn: 2126700804 244120117 not found on unit
# - component fru sn: astfwi235001849 not found on unit
# - component fru sn: 2468056-1 242069728 not found on unit
# - component fru sn: astfwi250200143 not found on unit
# - component fru sn: 2468056-1 245131442 not found on unit
# - component sn: habqtw250215583 not found on unit
# - component sn: pdfqmb243203199 not found on unit
# - component fru sn: 2468056-1 243078077 not found on unit
# - component fru sn: lz6pe005-sd-r 884969409 not found on unit
# - component sn: ipbfwi250201179 not found on unit
# - component sn: pdfcth244302088 not found on unit
# - component fru sn: 2468056-1 24510ac4w not found on unit
# - component fru sn: 2468056-1 244944814 not found on unit
# - component fru sn: astfwi250605996 not found on unit
# - component fru sn: 2468056-1 250130bev not found on unit
# - component fru sn: 2468056-1 24510apue not found on unit
# - component fru sn: astfwi241101102 not found on unit
# - component sn: ipbfwi250105748 not found on unit
# - component sn: pdfcth241901845 not found on unit
# - component fru sn: lz6pe005-sd-r 244817424 not found on unit
# - component fru sn: 2468056-1 244534939 not found on unit
# - component fru sn: 2468056-1 24510bg9c not found on unit
# - component fru sn: 2468056-1 2452000kr not found on unit
# - component fru sn: 2468056-1 2452020vw not found on unit
# - component fru sn: astfwi245000181 not found on unit
# - component fru sn: 2411266-1 234440051 not found on unit
# - component fru sn: 2126700804 244720120 not found on unit
# - component fru sn: 2468056-1 250201kep not found on unit
# - component fru sn: astfwi242604231 not found on unit
# - component fru sn: 2468056-1 24510b6ve not found on unit
# - component fru sn: 2409682-1 224263265 not found on unit
# - component sn: kw049419-96402 40419038 not found on unit
# - component sn: ipbfwi250702690 not found on unit
# - component sn: kw049419-96402 43204907 not found on unit
# - component sn: ipbfwi250208680 not found on unit
# - component fru sn: 2468056-1 24510a39e not found on unit
# - component fru sn: lz6pe005-sd-r 244970399 not found on unit
# - component sn: habqtw245141815 not found on unit
# - component sn: ipbfwi235100935 not found on unit
# - component sn: ipbfwi242502313 not found on unit
# - component fru sn: 2468056-1 245201991 not found on unit
# - component fru sn: 2468056-1 242399989 not found on unit
# - component fru sn: 2411266-1 241310730 not found on unit
# - component fru sn: aahivt243901573 not found on unit
# - component fru sn: 2409682-1 224061113 not found on unit
# - component fru sn: astfwi245000491 not found on unit
# - component fru sn: 2468056-1 250100b2g not found on unit
# - component fru sn: astivt244500319 not found on unit
# - component sn: kw049419-96402 43916470 not found on unit
# - component fru sn: 2468056-1 245277710 not found on unit
# - component sn: kw049419-96402 43521676 not found on unit
# - component fru sn: 2468056-1 241717076 not found on unit
# - component sn: ipbfwi250800956 not found on unit
# - component fru sn: 2468056-1 2502008ru not found on unit
# - component sn: pdfcth243605706 not found on unit
# - component fru sn: 2468056-1 245049135 not found on unit
# - component fru sn: aahfwi245107965 not found on unit
# - component sn: ipbfwi240900701 not found on unit
# - component fru sn: lz6pe005-sd-r 244905273 not found on unit
# - component fru sn: 2468056-1 243368116 not found on unit
# - component fru sn: lz6pe005-sd-r 244810287 not found on unit
# - component fru sn: 2409682-1 223960394 not found on unit
# - component fru sn: 2468056-1 24510b68f not found on unit
# - component sn: ipbfwi250503119 not found on unit
# - component sn: ipbfwi240100114 not found on unit
# - component fru sn: 2411266-1 234431206 not found on unit
# - component sn: kw049419-96402 41720569 not found on unit
# - component sn: habqtw250302418 not found on unit
# - component fru sn: 2468056-1 24510bb67 not found on unit
# - component fru sn: 2468056-1 244838457 not found on unit
# - component fru sn: 2468056-1 24510a39v not found on unit
# - component fru sn: rc164-2293 245023431 not found on unit
# - component fru sn: 2411266-1 234419802 not found on unit
# - component fru sn: rc164-2293 245124848 not found on unit
# - component sn: ipbfwi250109906 not found on unit
# - component sn: ipbfwi241102472 not found on unit
# - component fru sn: 2468056-1 244730107 not found on unit
# - component fru sn: 2468056-1 244745201 not found on unit
# - component fru sn: 2126700804 244820409 not found on unit
# - component fru sn: 2468056-1 2452006g5 not found on unit
# - component fru sn: 2468056-1 2452019aw not found on unit
# - component sn: pdfcth250210122 not found on unit
# - component sn: kw049419-96402 42606852 not found on unit
# - component fru sn: 2468056-1 244805029 not found on unit
# - component fru sn: lz6pe005-sd-r 244816332 not found on unit
# - component fru sn: 2411266-1 234448891 not found on unit
# - component sn: habqtw245207820 not found on unit
# - component fru sn: 2468056-1 244658690 not found on unit
# - component fru sn: 2468056-1 245029248 not found on unit
# - component fru sn: lz6pe005-sd-r 244530641 not found on unit
# - component fru sn: 2411266-1 241005389 not found on unit
# - component fru sn: 2468056-1 244664946 not found on unit
# - component fru sn: 2468056-1 243199116 not found on unit
# - component fru sn: 2468056-1 243883287 not found on unit
# - component pn: 1158718-03 not match unit pn: 1158718-02
# - component fru sn: astfwi245000358 not found on unit
# - component fru sn: 2468056-1 244612097 not found on unit
# - component sn: ipbfwi250105703 not found on unit
# - component sn: ipbfwi235100735 not found on unit
# - component fru sn: astivt242800996 not found on unit
# - component fru sn: 2468056-1 24510apd3 not found on unit
# - component sn: ipbfwi243701514 not found on unit
# - component fru sn: aahivt244503798 not found on unit
# - component sn: habqtw244115491 not found on unit
# - component sn: kw049419-96402 41707484 not found on unit
# - component fru sn: lz6pe005-sd-r 244920717 not found on unit
# - component fru sn: 2468056-1 2452017dl not found on unit
# - component fru sn: 2468056-1 244522919 not found on unit
# - component fru sn: astfwi245000346 not found on unit
# - component fru sn: aahfwi240101909 not found on unit
# - component fru sn: 2468056-1 244997096 not found on unit
# - component fru sn: 2468056-1 243885747 not found on unit
# - component sn: ipbfwi242100245 not found on unit
# - component fru sn: lz6pe005-sd-r 244811035 not found on unit
# - component fru sn: lz6pe005-sd-r 244501415 not found on unit
# - component fru sn: 2468056-1 244661039 not found on unit
# - component fru sn: 2126700804 244920864 not found on unit
# - component fru sn: lz6pe005-sd-r 244600517 not found on unit
# - component fru sn: 2468056-1 243489090 not found on unit
# - component fru sn: astfwi245000162 not found on unit
# - component sn: ipbfwi250403116 not found on unit
# - component fru sn: 2468056-1 24510b4re not found on unit
# - component sn: ipbfwi242701497 not found on unit
# - component fru sn: 2468056-1 244658924 not found on unit
# - component sn: ipbfwi241001061 not found on unit
# - component fru sn: 2468056-1 2504001vn not found on unit
# - component fru sn: 2468056-1 24510alr9 not found on unit
# - component sn: ipbfwi242902691 not found on unit
# - component fru sn: 2468056-1 244716956 not found on unit
# - component fru sn: 2468056-1 242069346 not found on unit
# - component sn: pdfcth244704276 not found on unit
# - component sn: kw049419-96402 40311341 not found on unit
# - component fru sn: 2468056-1 2452023r7 not found on unit
# - component sn: ipbfwi250109261 not found on unit
# - component fru sn: 2409682-1 224772238 not found on unit
# - component fru sn: 2468056-1 245112579 not found on unit
# - component fru sn: astfwi245200075 not found on unit
# - component fru sn: 2468056-1 244522866 not found on unit
# - component fru sn: lz6pe005-sd-r 244806348 not found on unit
# - component fru sn: 2411266-1 241005680 not found on unit
# - component fru sn: 2468056-1 241823265 not found on unit
# - component fru sn: 2411266-1 234444992 not found on unit
# - component fru sn: 2468056-1 245200de1 not found on unit
# - component fru sn: 2468056-1 245028337 not found on unit
# - component sn: ipbfwi250105751 not found on unit
# - component fru sn: 2468056-1 241818761 not found on unit
# - component fru sn: rc164-2293 245112310 not found on unit
# - component sn: ipbfwi235100973 not found on unit
# - component fru sn: 2468056-1 245200n3j not found on unit
# - component sn: kw049419-96402 41607950 not found on unit
# - component fru sn: 2468056-1 245201dn0 not found on unit
# - component fru sn: 2468056-1 245121759 not found on unit
# - component sn: kw049419-96402 40310369 not found on unit
# - component fru sn: 2468056-1 244816193 not found on unit
# - component fru sn: 2411266-1 234415205 not found on unit
# - component sn: ipbfwi250110223 not found on unit
# - component fru sn: 2468056-1 24520168t not found on unit
# - component fru sn: 2468056-1 24510a2he not found on unit
# - component sn: ipbfwi242104327 not found on unit
# - component fru sn: 2468056-1 250200au0 not found on unit
# - component fru pn: 2468056-1 not match unit fru pn: 1181739-01
# - component fru sn: 2468056-1 245200c3v not found on unit
# - component fru sn: rc164-2293 244313022 not found on unit
# - component sn: kw049419-96402 43205354 not found on unit
# - component sn: kw049419-96402 43607123 not found on unit
# - component fru sn: 2468056-1 244726529 not found on unit
# - component fru sn: lz6pe005-sd-r 244805043 not found on unit
# - component fru sn: 2468056-1 2452017la not found on unit
# - component fru sn: 2468056-1 244516745 not found on unit
# - component sn: ipbfwi240401847 not found on unit
# - component fru sn: 2468056-1 24510bgh9 not found on unit
# - component fru sn: 2468056-1 242069787 not found on unit
# - component fru sn: aahfwi250100243 not found on unit
# - component fru sn: 2411266-1 240420941 not found on unit
# - component fru sn: rc164-2293 245204137 not found on unit
# - component sn: ipbfwi240502198 not found on unit
# - component sn: ipbfwi244803693 not found on unit
# - component fru sn: 2468056-1 242689513 not found on unit
# - component fru sn: 2409682-1 222755437 not found on unit
# - component fru sn: lz6pe005-sd-r 244509004 not found on unit
# - component sn: kw049419-96402 43204492 not found on unit
# - component fru sn: 2468056-1 2504000p6 not found on unit
# - component fru sn: 2468056-1 244944221 not found on unit
# - component fru sn: lz6pe005-sd-r 244918239 not found on unit
# - component sn: ipbfwi241100171 not found on unit
# - component fru sn: 2411266-1 234433872 not found on unit
# - component sn: kw049419-96402 43915137 not found on unit
# - component fru sn: 2468056-1 244613136 not found on unit
# - component fru sn: astfwi245000337 not found on unit
# - component sn: ipbfwi242901041 not found on unit
# - component fru sn: lz6pe005-sd-r 244912307 not found on unit
# - component sn: ipbfwi243703741 not found on unit
# - component fru sn: 2468056-1 244766505 not found on unit
# - component sn: ipbfwi241001401 not found on unit
# - component fru sn: astfwi245200062 not found on unit
# - component sn: ipbfwi240200180 not found on unit
# - component fru sn: 2468056-1 245200ty1 not found on unit
# - component sn: habqtw245142016 not found on unit
# - component fru sn: astfwi250604184 not found on unit
# - component fru sn: astivt243402964 not found on unit
# - component sn: ipbfwi242105953 not found on unit
# - component fru sn: astivt244500401 not found on unit
# - component fru sn: astfwi240701612 not found on unit
# - component fru pn: 1139708-02 not match unit fru pn: 1139708-01
# - component fru sn: astivt242502667 not found on unit
# - component fru sn: 2468056-1 242722460 not found on unit
# - component fru sn: 2468056-1 245201flt not found on unit
# - component fru sn: 2468056-1 24510a25e not found on unit
# - component sn: ipbfwi250600095 not found on unit
# - component sn: ipbfwi242200864 not found on unit
# - component fru sn: astfwi242901579 not found on unit
# - component fru sn: 2468056-1 24510bam8 not found on unit
# - component fru sn: 2411266-1 241000599 not found on unit
# - component sn: ipbfwi244608425 not found on unit
# - component fru sn: 2468056-1 244608164 not found on unit
# - component fru sn: lz6pe005-sd-r 244972559 not found on unit
# - component sn: ipbfwi240700286 not found on unit
# - component fru sn: 2468056-1 24510b56b not found on unit
# - component sn: kw049419-96402 50212954 not found on unit
# - component sn: habqtw245026709 not found on unit
# - component sn: kw049419-96402 42517287 not found on unit
# - component sn: ipbfwi235000317 not found on unit
# - component fru sn: 2468056-1 242069792 not found on unit
# - component fru sn: astfwi245000345 not found on unit
# - component fru sn: astfwi245200071 not found on unit
# - component sn: kw049419-96402 40316681 not found on unit
# - component fru sn: 2411266-1 241018004 not found on unit
# - component fru sn: astfwi245000456 not found on unit
# - component fru sn: 2468056-1 245200ghu not found on unit
# - component fru sn: 2411266-1 234435480 not found on unit
# - component fru sn: astfwi245200108 not found on unit
# - component fru sn: 2468056-1 244609907 not found on unit
# - component sn: ipbfwi250901150 not found on unit
# - component sn: ipbfwi243703508 not found on unit
# - component sn: pdfcth243622768 not found on unit
# - component fru sn: 2468056-1 242066960 not found on unit
# - component sn: kw049419-96402 41608856 not found on unit
# - component fru sn: 2468056-1 241817394 not found on unit
# - component sn: pdfcth243710706 not found on unit
# - component sn: habqtw245102130 not found on unit
# - component fru sn: 2468056-1 245201kpp not found on unit
# - component fru sn: astfwi241002726 not found on unit
# - component fru sn: aahfwi250103852 not found on unit
# - component fru sn: 2468056-1 2502022we not found on unit
# - component sn: ipbfwi250206918 not found on unit
# - component fru sn: 2468056-1 245200ydp not found on unit
# - component fru sn: 2468056-1 245009523 not found on unit
# - component fru sn: rc164-2293 244804917 not found on unit
# - component fru sn: rc164-2293 244206541 not found on unit
# - component fru sn: 2468056-1 2452017at not found on unit
# - component fru sn: 2468056-1 245201e0u not found on unit
# - component sn: habqtw245214408 not found on unit
# - component fru sn: aahivt243201384 not found on unit
# - component fru sn: 2468056-1 2501003wt not found on unit
# - component fru sn: 2468056-1 244662355 not found on unit
# - component fru sn: lz6pe005-sd-r 244406522 not found on unit
# - component fru sn: astfwi244203679 not found on unit
# - component fru sn: 2468056-1 243884815 not found on unit
# - component fru sn: 2126700804 244320651 not found on unit
# - component sn: ipbfwi240200417 not found on unit
# - component fru sn: 2468056-1 2452000gp not found on unit
# - component sn: ipbfwi250400958 not found on unit
# - component fru sn: rc164-2293 245100354 not found on unit
# - component fru sn: 2468056-1 244656803 not found on unit
# - component fru sn: 2468056-1 244813451 not found on unit
# - component sn: kw049419-96402 43607728 not found on unit
# - component fru sn: 2468056-1 244609716 not found on unit
# - component sn: habqtw245123371 not found on unit
# - component fru sn: 2468056-1 244664077 not found on unit
# - component fru sn: 2409682-1 224977009 not found on unit
# - component fru sn: aahfwi245113558 not found on unit
# - component fru sn: 2468056-1 24510bara not found on unit
# - component fru sn: 2468056-1 24510bjau not found on unit
# - component sn: ipbfwi250805457 not found on unit
# - component fru sn: 2468056-1 244886472 not found on unit
# - component fru sn: 2411266-1 240439882 not found on unit
# - component fru sn: 2409682-1 224669900 not found on unit
# - component fru sn: aahivt243901423 not found on unit
# - component fru sn: astfwi245000239 not found on unit
# - component fru sn: 2468056-1 24510apr1 not found on unit
# - component fru sn: rc164-2293 245114386 not found on unit
# - component fru sn: 2468056-1 2452014dw not found on unit
# - component fru sn: astfwi245000453 not found on unit
# - component fru sn: 2468056-1 244609859 not found on unit
# - component fru sn: lz6pe005-sd-r 244600047 not found on unit
# - component fru sn: lz6pe005-sd-r 244607809 not found on unit
# - component fru sn: 2468056-1 2452019g9 not found on unit
# - component fru sn: 2468056-1 2452019ej not found on unit
# - component fru sn: astfwi241302227 not found on unit
# - component fru sn: 2468056-1 244717882 not found on unit
# - component fru sn: 2468056-1 250130bc1 not found on unit
# - component fru sn: 2468056-1 245201kyg not found on unit
# - component fru sn: 2468056-1 245201324 not found on unit
# - component sn: ipbfwi250110677 not found on unit
# - component sn: ipbfwi242702794 not found on unit
# - component fru sn: 2409682-1 223114625 not found on unit
# - component fru sn: 2468056-1 244514182 not found on unit
# - component fru sn: 2468056-1 245007466 not found on unit
# - component fru sn: astfwi245000043 not found on unit
# - component fru sn: lz6pe005-sd-r 244808650 not found on unit
# - component fru sn: 2409682-1 224569406 not found on unit
# - component fru sn: 2409682-1 225080257 not found on unit
# - component sn: ipbfwi243003690 not found on unit
# - component fru sn: lz6pe005-sd-r 244903540 not found on unit
# - component fru sn: 2409682-1 224773747 not found on unit
# - component sn: ipbfwi240100739 not found on unit
# - component fru sn: aahfwi245107848 not found on unit
# - component fru sn: 2409682-1 224977199 not found on unit
# - component fru sn: lz6pe005-sd-r 244600570 not found on unit
# - component fru sn: 2468056-1 25033019u not found on unit
# - component sn: ipbfwi241902677 not found on unit
# - component fru sn: astivt244001767 not found on unit
# - component fru sn: 2409682-1 221901033 not found on unit
# - component fru sn: 2468056-1 24510av64 not found on unit
# - component sn: ipbfwi244704901 not found on unit
# - component fru sn: 2468056-1 241716955 not found on unit
# - component sn: kw049419-96402 42512680 not found on unit
# - component fru sn: 2468056-1 2452017df not found on unit
# - component fru sn: 2468056-1 24510aunp not found on unit
# - component sn: ipbfwi250507011 not found on unit
# - component sn: ipbfwi241902425 not found on unit
# - component fru sn: 2468056-1 244919340 not found on unit
# - component fru sn: 2468056-1 241718525 not found on unit
# - component sn: ipbfwi235101761 not found on unit
# - component sn: kw049419-96402 42514240 not found on unit
# - component sn: ipbfwi244200244 not found on unit
# - component fru sn: astfwi245000209 not found on unit
# - component fru sn: 2468056-1 242070464 not found on unit
# - component fru sn: 2468056-1 244717753 not found on unit
# - component sn: habqtw245214804 not found on unit
# - component fru sn: 2468056-1 242069852 not found on unit
# - component fru sn: astfwi250200044 not found on unit
# - component fru sn: 2468056-1 244604479 not found on unit
# - component fru sn: 2468056-1 250200wfu not found on unit
# - component fru sn: astfwi243600748 not found on unit
# - component sn: kw049419-96402 50213108 not found on unit
# - component fru sn: astfwi250900536 not found on unit
# - component fru sn: 2468056-1 24510a2lt not found on unit
# - component fru sn: lz6pe005-sd-r 244812236 not found on unit
# - component fru sn: 2468056-1 244717590 not found on unit
# - component fru sn: 2468056-1 250230ag3 not found on unit
# - component fru sn: 2468056-1 250300puk not found on unit
# - component fru sn: 2409682-1 221901521 not found on unit
# - component fru sn: 2468056-1 245112954 not found on unit
# - component fru sn: rc164-2293 245103985 not found on unit
# - component fru sn: lz6pe005-sd-r 244816711 not found on unit
# - component fru sn: 2468056-1 24510a31f not found on unit
# - component sn: kw049419-96402 41605970 not found on unit
# - component sn: pdfcth244818066 not found on unit
# - component sn: pdfqmb243803294 not found on unit
# - component fru sn: lz6pe005-sd-r 244816195 not found on unit
# - component fru sn: lz6pe005-sd-r 244901225 not found on unit
# - component fru sn: 2468056-1 244553139 not found on unit
# - component fru sn: 2468056-1 250200y2v not found on unit
# - component fru sn: astfwi245000199 not found on unit
# - component fru sn: 2468056-1 2452028dl not found on unit
# - component sn: ipbfwi250908001 not found on unit
# - component fru sn: astfwi245000368 not found on unit
# - component fru sn: 2468056-1 244889583 not found on unit
# - component fru sn: 2468056-1 244944469 not found on unit
# - component fru sn: aahivt244401591 not found on unit
# - component fru pn: 1139708-02 not match unit fru pn: 1139228-03
# - component sn: ipbfwi240400335 not found on unit
# - component sn: pdfqmb244402459 not found on unit
# - component fru sn: lz6pe005-sd-r 244915244 not found on unit
# - component sn: kw049419-96402 41606066 not found on unit
# - component fru sn: astfwi245000210 not found on unit
# - component fru sn: 2468056-1 242069149 not found on unit
# - component fru sn: astfwi241101458 not found on unit
# - component fru sn: 2468056-1 242069441 not found on unit
# - component sn: pdfcth244807747 not found on unit
# - component fru sn: 2468056-1 244922278 not found on unit
# - component fru sn: astfwi241905239 not found on unit
# - component fru sn: 2468056-1 243598681 not found on unit
# - component fru sn: 2468056-1 2452017vj not found on unit
# - component sn: ipbfwi250305785 not found on unit
# - component fru sn: 2468056-1 242180357 not found on unit
# - component fru sn: 2409682-1 224671268 not found on unit
# - component sn: ipbfwi240802617 not found on unit
# - component fru sn: 2468056-1 244805728 not found on unit
# - component fru sn: 2411266-1 234420225 not found on unit
# - component sn: ipbfwi240501981 not found on unit
# - component fru sn: 2468056-1 244801021 not found on unit
# - component fru sn: 2468056-1 245200cr8 not found on unit
# - component sn: habqtw250207123 not found on unit
# - component fru sn: 2411266-1 234424571 not found on unit
# - component sn: ipbfwi250204791 not found on unit
# - component sn: ipbfwi242104321 not found on unit
# - component sn: habqtw245100077 not found on unit
# - component fru sn: 2468056-1 24520093l not found on unit
# - component fru sn: 2468056-1 245001271 not found on unit
# - component fru sn: 2468056-1 244535539 not found on unit
# - component fru sn: 2468056-1 245201cke not found on unit
# - component sn: ipbfwi244500006 not found on unit
# - component fru sn: lz6pe005-sd-r 244920072 not found on unit
# - component fru sn: aahfwi240900453 not found on unit
# - component fru sn: 2468056-1 24510agn6 not found on unit
# - component sn: ipbfwi240800285 not found on unit
# - component fru sn: 2468056-1 24510a2hn not found on unit
# - component fru sn: 2468056-1 245200a4j not found on unit
# - component fru sn: 2468056-1 245126297 not found on unit
# - component sn: kw049419-96402 42606150 not found on unit
# - component sn: ipbfwi244703670 not found on unit
# - component fru sn: lz6pe005-sd-r 244505428 not found on unit
# - component fru sn: 2468056-1 2452003hj not found on unit
# - component fru sn: 2468056-1 24510awhf not found on unit
# - component fru sn: astfwi240401286 not found on unit
# - component fru sn: 2468056-1 250101hl5 not found on unit
# - component fru sn: 2409682-1 222505639 not found on unit
# - component fru sn: rc164-2293 245007508 not found on unit
# - component fru sn: aahfwi244104700 not found on unit
# - component fru sn: 2409682-1 223105615 not found on unit
# - component sn: kw049419-96402 40413396 not found on unit
# - component fru sn: 2409682-1 224162724 not found on unit
# - component fru sn: 2468056-1 24510a383 not found on unit
# - component sn: pdfcth245006707 not found on unit
# - component fru sn: 2468056-1 245026641 not found on unit
# - component fru sn: 2468056-1 244731297 not found on unit
# - component sn: kw049419-48302 33102091 not found on unit
# - component fru sn: 2468056-1 2503300pw not found on unit
# - component fru sn: lz6pe005-sd-r 244913025 not found on unit
# - component fru sn: 2409682-1 224467204 not found on unit
# - component sn: habqtw245123811 not found on unit
# - component sn: ipbfwi243701209 not found on unit
# - component fru sn: rc164-2293 244509675 not found on unit
# - component fru sn: 2409682-1 224467023 not found on unit
# - component fru sn: astfwi244203729 not found on unit
# - component sn: ipbfwi242200708 not found on unit
# - component sn: ipbfwi250306428 not found on unit
# - component sn: pdfcth242213318 not found on unit
# - component fru sn: aahfwi250406386 not found on unit
# - component sn: ipbfwi250107559 not found on unit
# - component fru sn: 2468056-1 245201dkb not found on unit
# - component sn: kw049419-96402 40406914 not found on unit
# - component fru sn: aahfwi244400148 not found on unit
# - component sn: ipbfwi240802808 not found on unit
# - component fru sn: astivt244000680 not found on unit
# - component sn: habqtw250102770 not found on unit
# - component sn: ipbfwi244209542 not found on unit
# - component fru sn: astivt242802095 not found on unit
# - component fru sn: rc164-2293 244509296 not found on unit
# - component sn: ipbfwi250111648 not found on unit
# - component fru sn: astivt244201243 not found on unit
# - component sn: ipbfwi240500565 not found on unit
# - component fru sn: 2468056-1 2452007am not found on unit
# - component sn: pdfcth250422075 not found on unit
# - component fru sn: astivt243500584 not found on unit
# ...
# - component sn: kw049419-96402 41608725 not found on unit
# - component fru sn: 2468056-1 250200ljf not found on unit
# - component fru sn: lz6pe005-sd-r 244812676 not found on unit
# - component fru sn: lz6pe005-sd-r 244933537 not found on unit
# - component fru sn: 2468056-1 250202fra not found on unit
# - component fru sn: 2468056-1 244624124 not found on unit
# - component fru sn: 2468056-1 245201nkr not found on unit
# - component sn: kw049419-16401 33108772 not found on unit
# - component fru sn: aahfwi243404730 not found on unit
# - component fru sn: 2468056-1 243877126 not found on unit
# - component sn: habqtw245119327 not found on unit
# - component fru sn: lz6pe005-sd-r 244610653 not found on unit
# - component fru sn: lz6pe005-sd-r 244529983 not found on unit
# - component fru sn: astfwi241102852 not found on unit
# - component fru sn: 2468056-1 242069318 not found on unit
# - component fru sn: 2468056-1 244887115 not found on unit
# - component sn: habqtw245022688 not found on unit
# - component sn: ipbfwi240401844 not found on unit
# - component fru sn: 2468056-1 244518217 not found on unit
# - component fru sn: astivt244602940 not found on unit
# - component fru sn: lz6pe005-sd-r 244632529 not found on unit
# - component fru sn: 2468056-1 245200c4p not found on unit
# - component fru sn: 2468056-1 245201yu6 not found on unit
# - component fru sn: rc164-2293 244301265 not found on unit
# - component fru sn: 2468056-1 244105071 not found on unit
# - component fru sn: lz6pe005-sd-r 244917092 not found on unit
# - component sn: kw049419-96402 42413758 not found on unit
# - component sn: ipbfwi250210405 not found on unit
# - component sn: ipbfwi244600131 not found on unit
# - component sn: ipbfwi241700728 not found on unit
# - component fru sn: 2468056-1 245200g2y not found on unit
# - component fru sn: 2468056-1 245113147 not found on unit
# - component fru sn: 2409682-1 225181438 not found on unit
# - component fru sn: 2468056-1 245200dvf not found on unit
# - component fru sn: 2468056-1 245201d5k not found on unit
# - component fru sn: 2468056-1 2452003fc not found on unit
# - component fru sn: 2468056-1 24510a3fp not found on unit
# - component fru sn: 2409682-1 225181371 not found on unit
# - component fru sn: astivt242702801 not found on unit
# - component fru sn: 2468056-1 24510arb4 not found on unit
# - component fru sn: lz6pe005-sd-r 244935483 not found on unit
# - component sn: ipbfwi240401733 not found on unit
# - component fru sn: astfwi244203687 not found on unit
# - component fru sn: 2468056-1 245200et8 not found on unit
# - component sn: kw049419-96402 41707284 not found on unit
# - component fru sn: 2468056-1 2452011d7 not found on unit
# - component sn: kw049419-96402 40402083 not found on unit
# - component fru sn: 2409682-1 224977937 not found on unit
# - component fru sn: 2468056-1 245200kk6 not found on unit
# - component fru sn: 2468056-1 244709394 not found on unit
# - component fru sn: 2468056-1 244609856 not found on unit
# - component fru sn: 2468056-1 242744264 not found on unit
# - component fru sn: 2126700804 244720184 not found on unit
# - component sn: ipbfwi250200187 not found on unit
# - component sn: kw049419-96502 40521329 not found on unit
# - component fru sn: 2411266-1 234433191 not found on unit
# - component fru sn: 2468056-1 245044925 not found on unit
# - component fru sn: aahfwi240901746 not found on unit
# - component sn: ipbfwi250402062 not found on unit
# - component fru sn: rc164-2293 244509278 not found on unit
# - component fru sn: lz6pe005-sd-r 244615506 not found on unit
# - component fru sn: 2468056-1 245123093 not found on unit
# - component fru sn: 2468056-1 245121620 not found on unit
# - component fru sn: astfwi245200109 not found on unit
# - component fru sn: 2468056-1 244937127 not found on unit
# - component sn: ipbfwi243703509 not found on unit
# - component sn: habqtw250210332 not found on unit
# - component fru sn: aahfwi245106047 not found on unit
# - component fru sn: 2468056-1 2502018ua not found on unit
# - component fru sn: 2468056-1 244526870 not found on unit
# - component fru sn: 2468056-1 244995204 not found on unit
# - component fru sn: astfwi235000659 not found on unit
# - component fru sn: aahivt244902296 not found on unit
# - component sn: ipbfwi235101459 not found on unit
# - component fru sn: 2468056-1 24520170p not found on unit
# - component fru sn: 2411266-1 234405349 not found on unit
# - component sn: pdfcth245013423 not found on unit
# - component sn: ipbfwi243800304 not found on unit
# - component fru sn: 2468056-1 245130357 not found on unit
# - component sn: ipbfwi250211833 not found on unit
# - component fru sn: astfwi245000379 not found on unit
# - component fru sn: 2409682-1 224061017 not found on unit
# - component fru sn: astfwi244203643 not found on unit
# - component fru sn: lz6pe005-sd-r 244916484 not found on unit
# - component fru sn: 2468056-1 250300vmr not found on unit
# - component fru sn: 2468056-1 24510a1d6 not found on unit
# - component fru sn: 2468056-1 250300y7l not found on unit
# - component sn: ipbfwi244203829 not found on unit
# - component sn: ipbfwi240100397 not found on unit
# - component sn: pdfqmb244103418 not found on unit
# - component fru sn: astfwi244500854 not found on unit
# - component sn: kw049419-96402 43915292 not found on unit
# - component fru sn: astivt243402376 not found on unit
# - component fru sn: 2468056-1 2452003kd not found on unit
# - component sn: kw049419-96402 50215321 not found on unit
# - component sn: ipbfwi240801009 not found on unit
# - component fru sn: 2409682-1 223109142 not found on unit
# - component sn: ipbfwi250209158 not found on unit
# - component fru sn: 2468056-1 244992591 not found on unit
# - component sn: ipbfwi243703538 not found on unit
# - component fru sn: 2468056-1 2504009t2 not found on unit
# - component fru sn: 2411266-1 241012869 not found on unit
# - component fru sn: 2468056-1 2452001v7 not found on unit
# - component fru sn: astfwi240400608 not found on unit
# - component pn:  1170656-01 not match unit pn: 1170656-01
# - component fru sn: 2468056-1 244511856 not found on unit
# - component fru sn: 2468056-1 24510b6cf not found on unit
# - component sn: kw049419-96402 42414271 not found on unit
# - component fru sn: aahfwi250405277 not found on unit
# - component sn: ipbfwi242105832 not found on unit
# - component fru sn: 2468056-1 24520189u not found on unit
# - component sn: ipbfwi241001152 not found on unit
# - component fru sn: 2468056-1 24520170b not found on unit
# - component fru sn: lz6pe005-sd-r 244815669 not found on unit
# - component sn: pdfcth245012282 not found on unit
# - component sn: ipbfwi242105519 not found on unit
# - component sn: ipbfwi243804724 not found on unit
# - component fru sn: 2468056-1 245001347 not found on unit
# - component sn: habqtw245104075 not found on unit
# - component fru sn: 2468056-1 2452016wf not found on unit
# - component sn: ipbfwi243701436 not found on unit
# - component sn: kw049419-96402 43204861 not found on unit
# - component fru sn: rc164-2293 245114249 not found on unit
# - component sn: ipbfwi243703517 not found on unit
# - component fru sn: astfwi245000194 not found on unit
# - component fru sn: 2411266-1 240421222 not found on unit
# - component fru sn: 2126700804 244622659 not found on unit
# - component fru sn: rc164-2293 244717606 not found on unit
# - component fru sn: astfwi243403035 not found on unit
# - component sn: pdfcth244801142 not found on unit
# - component fru sn: astfwi245000198 not found on unit
# - component fru sn: aahfwi245110571 not found on unit
# - component fru sn: lz6pe005-sd-r 244947626 not found on unit
# - component fru sn: lz6pe005-sd-r 244406775 not found on unit
# - component sn: pdfqmb244100367 not found on unit
# - component fru sn: 2468056-1 2501307vd not found on unit
# - component fru sn: lz6pe005-sd-r 244942699 not found on unit
# - component fru sn: 2468056-1 244614943 not found on unit
# - component fru sn: astfwi245000443 not found on unit
# - component sn: ipbfwi250802366 not found on unit
# - component fru sn: lz6pe005-sd-r 244810144 not found on unit
# - component fru sn: 2468056-1 244627045 not found on unit
# - component sn: ipbfwi240100582 not found on unit
# - component fru sn: 2468056-1 244414803 not found on unit
# - component fru sn: 2468056-1 244664216 not found on unit
# - component sn: habqtw245136435 not found on unit
# - component fru sn: 2409682-1 224568961 not found on unit
# - component fru sn: astfwi243606336 not found on unit
# - component fru sn: 2409682-1 221902835 not found on unit
# - component fru sn: 2468056-1 245023688 not found on unit
# - component sn: habqtw245211674 not found on unit
# - component fru sn: 2468056-1 245007884 not found on unit
# - component fru sn: lz6pe005-sd-r 244402709 not found on unit
# - component fru sn: aahfwi245110948 not found on unit
# - component sn: ipbfwi243005494 not found on unit
# - component fru sn: 2468056-1 250300r7u not found on unit
# - component fru sn: 2411266-1 234428215 not found on unit
# - component fru sn: lz6pe005-sd-r 244970338 not found on unit
# - component fru sn: 2468056-1 243082004 not found on unit
# - component fru sn: 2468056-1 245200nup not found on unit
# - component fru sn: 2126700804 244220949 not found on unit
# - component fru sn: 2468056-1 245200c8n not found on unit
# - component fru sn: astfwi242904580 not found on unit
# - component sn: kw049419-96402 42512273 not found on unit
# - component fru sn: 2468056-1 24510bacr not found on unit
# - component fru sn: lz6pe005-sd-r 244622745 not found on unit
# - component sn: ipbfwi250206031 not found on unit
# - component fru sn: 2468056-1 244944312 not found on unit
# - component fru sn: rc164-2293 245032366 not found on unit
# - component fru sn: astfwi250200208 not found on unit
# - component fru sn: aahivt250203582 not found on unit
# - component fru sn: lz6pe005-sd-r 244915637 not found on unit
# - component sn: ipbfwi240700043 not found on unit
# - component sn: pdfcth244302603 not found on unit
# - component fru sn: astfwi245000170 not found on unit
# - component fru sn: 2411266-1 234426425 not found on unit
# - component fru sn: 2409682-1 224671209 not found on unit
# - component fru sn: 2468056-1 25010055y not found on unit
# - component sn: ipbfwi235101593 not found on unit
# - component fru sn: lz6pe005-sd-r 244915868 not found on unit
# - component fru sn: lz6pe005-sd-r 244816502 not found on unit
# - component fru sn: 2468056-1 24510awbc not found on unit
# - component fru sn: 2468056-1 244658947 not found on unit
# - component fru sn: astfwi245000002 not found on unit
# - component fru sn: 2468056-1 244530001 not found on unit
# - component fru sn: aahfwi234102187 not found on unit
# - component sn: ipbfwi243800826 not found on unit
# - component fru sn: lz6pe005-sd-r 244910408 not found on unit
# - component sn: kw049419-96402 42512846 not found on unit
# - component sn: ipbfwi250403739 not found on unit
# - component sn: habqtw245101656 not found on unit
# - component fru sn: 2468056-1 245014730 not found on unit
# - component fru sn: 2468056-1 250181145 not found on unit
# - component sn: kw049419-96402 42413751 not found on unit
# - component fru sn: 2468056-1 2504304wk not found on unit
# - component fru sn: 2468056-1 245201v6d not found on unit
# - component sn: kw049419-96402 41705223 not found on unit
# - component fru sn: 2409682-1 221901632 not found on unit
# - component fru sn: 2468056-1 244942667 not found on unit
# - component fru sn: rc164-2293 244304928 not found on unit
# - component sn: ipbfwi240401020 not found on unit
# - component fru sn: lz6pe005-sd-r 244910360 not found on unit
# - component fru sn: 2468056-1 243775215 not found on unit
# - component fru sn: astivt243302711 not found on unit
# - component fru sn: 2468056-1 245200cbf not found on unit
# - component sn: ipbfwi250402513 not found on unit
# - component sn: ipbfwi244704502 not found on unit
# - component fru sn: 2468056-1 244609738 not found on unit
# - component fru sn: 2468056-1 250202488 not found on unit
# - component fru sn: 2468056-1 244883577 not found on unit
# - component sn: ipbfwi244904187 not found on unit
# - component sn: ipbfwi240700664 not found on unit
# - component sn: ipbfwi250203338 not found on unit
# - component fru sn: 2468056-1 24510a0vr not found on unit
# - component sn: ipbfwi241001256 not found on unit
# - component fru sn: lz6pe005-sd-r 244600251 not found on unit
# - component fru sn: 2468056-1 25043032d not found on unit
# - component sn: kw049419-96402 50213115 not found on unit
# - component fru sn: 2468056-1 244947640 not found on unit
# - component fru sn: aahivt243803210 not found on unit
# - component fru sn: aahfwi250500457 not found on unit
# - component sn: ipbfwi244207713 not found on unit
# - component fru sn: 2468056-1 244610148 not found on unit
# - component fru sn: 2468056-1 244510458 not found on unit
# - component fru sn: 2468056-1 245200e27 not found on unit
# - component sn: pdfcth244904070 not found on unit
# - component fru sn: lz6pe005-sd-r 244907756 not found on unit
# - component fru sn: 2468056-1 24510bb6t not found on unit
# - component sn: kw049419-96402 41708154 not found on unit
# - component fru sn: 2468056-1 243705012 not found on unit
# - component sn: ipbfwi243703469 not found on unit
# - component fru sn: lz6pe005-sd-r 244303140 not found on unit
# - component fru sn: 2468056-1 250300y3v not found on unit
# - component fru pn: 1119041-07 not match unit fru pn: 1119041-06
# - component fru sn: 2468056-1 24510a0t9 not found on unit
# - component sn: pdfcth243709098 not found on unit
# - component fru sn: 2468056-1 244737086 not found on unit
# - component sn: kw049419-96402 41707745 not found on unit
# - component fru sn: 2468056-1 244633420 not found on unit
# - component fru sn: 2468056-1 241700810 not found on unit
# - component fru sn: 2468056-1 241420918 not found on unit
# - component fru sn: astivt244301739 not found on unit
# - component sn: habqtw245140915 not found on unit
# - component fru sn: 2468056-1 241716901 not found on unit
# - component fru sn: astfwi245000233 not found on unit
# - component fru sn: 2468056-1 243259453 not found on unit
# - component sn: ipbfwi242105897 not found on unit
# - component fru sn: 2468056-1 24510arku not found on unit
# - component fru sn: 2468056-1 244605605 not found on unit
# - component sn: kw049419-96402 42414041 not found on unit
# - component fru sn: lz6pe005-sd-r 244916228 not found on unit
# - component fru sn: 2468056-1 241704474 not found on unit
# - component sn: ipbfwi241100516 not found on unit
# - component fru sn: lz6pe005-sd-r 244947110 not found on unit
# - component fru sn: rc164-2293 245122667 not found on unit
# - component sn: habqtw243915082 not found on unit
# - component fru sn: 2468056-1 244927497 not found on unit
# - component fru sn: 2468056-1 244745177 not found on unit
# - component sn: ipbfwi234500045 not found on unit
# - component fru sn: 2468056-1 244804232 not found on unit
# - component fru sn: lz6pe005-sd-r 244601888 not found on unit
# - component sn: pdfqmb242200417 not found on unit
# - component sn: pdfcth244905980 not found on unit
# - component fru sn: 2468056-1 244529604 not found on unit
# - component fru sn: 2468056-1 244627836 not found on unit
# - component fru sn: 2468056-1 250101cv2 not found on unit
# - component fru sn: 2468056-1 241401556 not found on unit
# - component sn: kw049419-96402 43205346 not found on unit
# - component fru sn: aahivt243700871 not found on unit
# - component fru sn: astfwi241401726 not found on unit
# - component fru sn: aahfwi240601688 not found on unit
# - component fru sn: 2468056-1 245200tvw not found on unit
# - component fru sn: 2468056-1 24510adjw not found on unit
# - component fru sn: astivt244400917 not found on unit
# - component fru sn: 2468056-1 244714892 not found on unit
# - component fru sn: 2409682-1 224671177 not found on unit
# - component fru sn: 2468056-1 24510b65d not found on unit
# - component sn: ipbfwi242801631 not found on unit
# - component fru sn: 2468056-1 244717907 not found on unit
# - component fru sn: 2468056-1 244950235 not found on unit
# - component fru sn: lz6pe005-sd-r 244814355 not found on unit
# - component fru sn: 2411266-1 234408177 not found on unit
# - component sn: pdfcth224909447 not found on unit
# - component fru sn: lz6pe005-sd-r 244927855 not found on unit
