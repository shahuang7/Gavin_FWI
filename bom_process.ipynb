# %%
import pandas as pd

# %%
# bom_df = pd.read_excel('1182051_bom.XLSX')[['Item Number', 'Component number', 'Object description', 'Assembly indicator']]
# bom_df.to_csv('1182051_bom.csv', index=False)
bom_df = pd.read_csv('1182051_bom.csv')

# %%
# Step 1: Reset and group based on NaNs again (first group starts before first NaN)
bom_df['group'] = bom_df['Item Number'].isna().cumsum()

# Step 2: Prepare first group (top-level assembly) and set top-level parent
first_group = bom_df[bom_df['group'] == 0].copy()
parent_tree = {"1182051": {"Components": []}}

# Helper: Find alternates within a group (by duplicate Item Number)
def get_alternates_by_item(df_group):
    item_counts = df_group['Item Number'].value_counts()
    alt_item_numbers = item_counts[item_counts > 1].index
    alternates = {}
    for item_no in alt_item_numbers:
        items = df_group[df_group['Item Number'] == item_no]['Component number'].tolist()
        if len(items) > 1:
            alternates[item_no] = items
    return alternates

# Helper: Get next group for a component
def get_group_after_component(component_num):
    idx = bom_df[bom_df['Component number'] == component_num].index
    if len(idx) == 0:
        return pd.DataFrame()
    idx = idx[0]
    subsequent = bom_df[bom_df.index > idx]
    if subsequent.empty:
        return pd.DataFrame()
    group_id = subsequent.iloc[0]['group']
    return bom_df[bom_df['group'] == group_id].copy()

# Step 3: Process the first group
alt_by_item = get_alternates_by_item(first_group)
components_info = []

for _, row in first_group.iterrows():
    comp = row['Component number']
    item_no = row['Item Number']
    desc = row['Object description']
    is_assembly = str(row['Assembly indicator']).strip().lower() == 'yes'
    
    entry = {
        "Component": comp,
        "Item Number": item_no,
        "Description": desc,
        "Assembly": is_assembly,
        "Alternates": [],
        "Subcomponents": []
    }

    # If this item number has alternates
    if item_no in alt_by_item and comp in alt_by_item[item_no]:
        entry["Alternates"] = [c for c in alt_by_item[item_no] if c != comp]

    # If this is an assembly and contains 'Option' in description → its alternates are in the next group
    if is_assembly and 'option' in str(desc).lower():
        subgroup = get_group_after_component(comp)
        if not subgroup.empty:
            alt_group_by_item = get_alternates_by_item(subgroup)
            for _, subrow in subgroup.iterrows():
                subcomp = subrow['Component number']
                subitem_no = subrow['Item Number']
                if subitem_no in alt_group_by_item:
                    entry["Subcomponents"].append({
                        "Component": subcomp,
                        "Item Number": subitem_no,
                        "Alternates": alt_group_by_item[subitem_no]
                    })

    components_info.append(entry)

# Final structure
parent_tree["1182051"]["Components"] = components_info
parent_tree
# Out:
# {'1182051': {'Components': [{'Component': '1136907-01',
#     'Item Number': 10.0,
#     'Description': 'Assy, Diorite B1 FullRock 48GB, 1x200GbE',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1107157-01',
#     'Item Number': 20.0,
#     'Description': 'Cable, HDMI, Standard Type A Male-to- St',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1098823-01',
#     'Item Number': 30.0,
#     'Description': 'Cable, Power, Diorite to Dedicated Conn,',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1112593-02',
#     'Item Number': 40.0,
#     'Description': 'ASM, Tray Cover, Air Baffle, Astoria, EV',
#     'Assembly': False,
#     'Alternates': ['1112593-02-FLG'],
#     'Subcomponents': []},
#    {'Component': '1112593-02-FLG',
#     'Item Number': 40.0,
#     'Description': 'ASM, Tray Cover, Air Baffle, Astoria(FLE',
#     'Assembly': False,
#     'Alternates': ['1112593-02'],
#     'Subcomponents': []},
#    {'Component': '1134400',
#     'Item Number': 50.0,
#     'Description': 'Assy, x16x16 IO Module',
#     'Assembly': False,
#     'Alternates': ['1134400-01',
#      '1134400-01-FGZ',
#      '1134400-01-FLG',
#      '1134400-FLG'],
#     'Subcomponents': []},
#    {'Component': '1134400-01',
#     'Item Number': 50.0,
#     'Description': 'Assy, x16x16 IO Module Bracket, Improved',
#     'Assembly': False,
#     'Alternates': ['1134400',
#      '1134400-01-FGZ',
#      '1134400-01-FLG',
#      '1134400-FLG'],
#     'Subcomponents': []},
#    {'Component': '1134400-01-FGZ',
#     'Item Number': 50.0,
#     'Description': 'Assy, x16x16 IO Module Bracket, Improved',
#     'Assembly': False,
#     'Alternates': ['1134400', '1134400-01', '1134400-01-FLG', '1134400-FLG'],
#     'Subcomponents': []},
#    {'Component': '1134400-01-FLG',
#     'Item Number': 50.0,
#     'Description': 'Assy, x16x16 IO Module Bracket, Improved',
#     'Assembly': False,
#     'Alternates': ['1134400', '1134400-01', '1134400-01-FGZ', '1134400-FLG'],
#     'Subcomponents': []},
#    {'Component': '1134400-FLG',
#     'Item Number': 50.0,
#     'Description': 'Assy, x16x16 IO Module Bracket, Improved',
#     'Assembly': False,
#     'Alternates': ['1134400',
#      '1134400-01',
#      '1134400-01-FGZ',
#      '1134400-01-FLG'],
#     'Subcomponents': []},
#    {'Component': '1114467',
#     'Item Number': 60.0,
#     'Description': 'Screw, Flathead, Low thickness head, Phi',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1136798',
#     'Item Number': 70.0,
#     'Description': 'Options, CSSD-PH2X, PCBA, 128GB Raw, 100',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': [{'Component': '1112593-02',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1112593-02-FLG',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1134400',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FGZ',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']}]},
#    {'Component': '1136856-03',
#     'Item Number': 80.0,
#     'Description': 'Option, Cable, PCIe Cable, 1 x16 Short I',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': [{'Component': '1112593-02',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1112593-02-FLG',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1134400',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FGZ',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']}]},
#    {'Component': '1182049',
#     'Item Number': 100.0,
#     'Description': 'Option, Memory, 64GB, 10x4, 2Rx4 RANK, D',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': [{'Component': '1112593-02',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1112593-02-FLG',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1134400',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FGZ',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']}]},
#    {'Component': '1182060',
#     'Item Number': 110.0,
#     'Description': 'Option, PCBA, Habanero16, Interface Card',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': [{'Component': '1112593-02',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1112593-02-FLG',
#       'Item Number': 40.0,
#       'Alternates': ['1112593-02', '1112593-02-FLG']},
#      {'Component': '1134400',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FGZ',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-01-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']},
#      {'Component': '1134400-FLG',
#       'Item Number': 50.0,
#       'Alternates': ['1134400',
#        '1134400-01',
#        '1134400-01-FGZ',
#        '1134400-01-FLG',
#        '1134400-FLG']}]},
#    {'Component': '07087259',
#     'Item Number': 120.0,
#     'Description': 'Label, Blank, White, 0.25" x 1.25", Poly',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1150248',
#     'Item Number': 130.0,
#     'Description': 'LABEL, SYSTEM, agency, Astoria, COO Fii',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1117606-01',
#     'Item Number': 140.0,
#     'Description': 'Packaging, Top Level Assembly, Truck Pac',
#     'Assembly': False,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1154335',
#     'Item Number': 150.0,
#     'Description': 'Assy, Tray, ASTORIA, Base Config, PRD 96',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': []},
#    {'Component': '1174345',
#     'Item Number': 160.0,
#     'Description': 'Option, Assy, PDB Power Module, Gulp 150',
#     'Assembly': True,
#     'Alternates': [],
#     'Subcomponents': [{'Component': '1123935',
#       'Item Number': 10.0,
#       'Alternates': ['1123935', '1123935-FMP']},
#      {'Component': '1123935-FMP',
#       'Item Number': 10.0,
#       'Alternates': ['1123935', '1123935-FMP']}]}]}}

# %%
# Flatten the hierarchical structure into rows for a DataFrame
flattened_rows = []

parent = "1182051"
for comp in parent_tree[parent]["Components"]:
    base_row = {
        "Parent": parent,
        "Component": comp["Component"],
        "Item Number": comp["Item Number"],
        "Description": comp["Description"],
        "Assembly": comp["Assembly"],
        "Level": "Main",
        "Alternate Of": None
    }
    flattened_rows.append(base_row)
    
    # Add alternates
    for alt in comp["Alternates"]:
        flattened_rows.append({
            "Parent": parent,
            "Component": alt,
            "Item Number": comp["Item Number"],
            "Description": None,
            "Assembly": False,
            "Level": "Alternate",
            "Alternate Of": comp["Component"]
        })
    
    # Add subcomponents
    for sub in comp.get("Subcomponents", []):
        flattened_rows.append({
            "Parent": comp["Component"],
            "Component": sub["Component"],
            "Item Number": sub["Item Number"],
            "Description": None,
            "Assembly": False,
            "Level": "Subcomponent",
            "Alternate Of": None
        })
        # Add alternates of subcomponent
        for alt in sub["Alternates"]:
            if alt != sub["Component"]:
                flattened_rows.append({
                    "Parent": comp["Component"],
                    "Component": alt,
                    "Item Number": sub["Item Number"],
                    "Description": None,
                    "Assembly": False,
                    "Level": "Sub-Alternate",
                    "Alternate Of": sub["Component"]
                })

# Convert to DataFrame
result_df = pd.DataFrame(flattened_rows)
result_df.head(20)
# Out:
#      Parent       Component  Item Number  \
# 0   1182051      1136907-01         10.0
# 1   1182051      1107157-01         20.0
# 2   1182051      1098823-01         30.0
# 3   1182051      1112593-02         40.0
# 4   1182051  1112593-02-FLG         40.0
# 5   1182051  1112593-02-FLG         40.0
# 6   1182051      1112593-02         40.0
# 7   1182051         1134400         50.0
# 8   1182051      1134400-01         50.0
# 9   1182051  1134400-01-FGZ         50.0
# 10  1182051  1134400-01-FLG         50.0
# 11  1182051     1134400-FLG         50.0
# 12  1182051      1134400-01         50.0
# 13  1182051         1134400         50.0
# 14  1182051  1134400-01-FGZ         50.0
# 15  1182051  1134400-01-FLG         50.0
# 16  1182051     1134400-FLG         50.0
# 17  1182051  1134400-01-FGZ         50.0
# 18  1182051         1134400         50.0
# 19  1182051      1134400-01         50.0
#
#                                  Description  Assembly      Level  \
# 0   Assy, Diorite B1 FullRock 48GB, 1x200GbE      True       Main
# 1   Cable, HDMI, Standard Type A Male-to- St     False       Main
# 2   Cable, Power, Diorite to Dedicated Conn,     False       Main
# 3   ASM, Tray Cover, Air Baffle, Astoria, EV     False       Main
# 4                                       None     False  Alternate
# 5   ASM, Tray Cover, Air Baffle, Astoria(FLE     False       Main
# 6                                       None     False  Alternate
# 7                     Assy, x16x16 IO Module     False       Main
# 8                                       None     False  Alternate
# 9                                       None     False  Alternate
# 10                                      None     False  Alternate
# 11                                      None     False  Alternate
# 12  Assy, x16x16 IO Module Bracket, Improved     False       Main
# 13                                      None     False  Alternate
# 14                                      None     False  Alternate
# 15                                      None     False  Alternate
# 16                                      None     False  Alternate
# 17  Assy, x16x16 IO Module Bracket, Improved     False       Main
# 18                                      None     False  Alternate
# 19                                      None     False  Alternate
#
#       Alternate Of
# 0             None
# 1             None
# 2             None
# 3             None
# 4       1112593-02
# 5             None
# 6   1112593-02-FLG
# 7             None
# 8          1134400
# 9          1134400
# 10         1134400
# 11         1134400
# 12            None
# 13      1134400-01
# 14      1134400-01
# 15      1134400-01
# 16      1134400-01
# 17            None
# 18  1134400-01-FGZ
# 19  1134400-01-FGZ

# %%
result_df[:50]
# Out:
#      Parent       Component  Item Number  \
# 0   1182051      1136907-01         10.0
# 1   1182051      1107157-01         20.0
# 2   1182051      1098823-01         30.0
# 3   1182051      1112593-02         40.0
# 4   1182051  1112593-02-FLG         40.0
# 5   1182051  1112593-02-FLG         40.0
# 6   1182051      1112593-02         40.0
# 7   1182051         1134400         50.0
# 8   1182051      1134400-01         50.0
# 9   1182051  1134400-01-FGZ         50.0
# 10  1182051  1134400-01-FLG         50.0
# 11  1182051     1134400-FLG         50.0
# 12  1182051      1134400-01         50.0
# 13  1182051         1134400         50.0
# 14  1182051  1134400-01-FGZ         50.0
# 15  1182051  1134400-01-FLG         50.0
# 16  1182051     1134400-FLG         50.0
# 17  1182051  1134400-01-FGZ         50.0
# 18  1182051         1134400         50.0
# 19  1182051      1134400-01         50.0
# 20  1182051  1134400-01-FLG         50.0
# 21  1182051     1134400-FLG         50.0
# 22  1182051  1134400-01-FLG         50.0
# 23  1182051         1134400         50.0
# 24  1182051      1134400-01         50.0
# 25  1182051  1134400-01-FGZ         50.0
# 26  1182051     1134400-FLG         50.0
# 27  1182051     1134400-FLG         50.0
# 28  1182051         1134400         50.0
# 29  1182051      1134400-01         50.0
# 30  1182051  1134400-01-FGZ         50.0
# 31  1182051  1134400-01-FLG         50.0
# 32  1182051         1114467         60.0
# 33  1182051         1136798         70.0
# 34  1136798      1112593-02         40.0
# 35  1136798  1112593-02-FLG         40.0
# 36  1136798  1112593-02-FLG         40.0
# 37  1136798      1112593-02         40.0
# 38  1136798         1134400         50.0
# 39  1136798      1134400-01         50.0
# 40  1136798  1134400-01-FGZ         50.0
# 41  1136798  1134400-01-FLG         50.0
# 42  1136798     1134400-FLG         50.0
# 43  1136798      1134400-01         50.0
# 44  1136798         1134400         50.0
# 45  1136798  1134400-01-FGZ         50.0
# 46  1136798  1134400-01-FLG         50.0
# 47  1136798     1134400-FLG         50.0
# 48  1136798  1134400-01-FGZ         50.0
# 49  1136798         1134400         50.0
#
#                                  Description  Assembly          Level  \
# 0   Assy, Diorite B1 FullRock 48GB, 1x200GbE      True           Main
# 1   Cable, HDMI, Standard Type A Male-to- St     False           Main
# 2   Cable, Power, Diorite to Dedicated Conn,     False           Main
# 3   ASM, Tray Cover, Air Baffle, Astoria, EV     False           Main
# 4                                       None     False      Alternate
# 5   ASM, Tray Cover, Air Baffle, Astoria(FLE     False           Main
# 6                                       None     False      Alternate
# 7                     Assy, x16x16 IO Module     False           Main
# 8                                       None     False      Alternate
# 9                                       None     False      Alternate
# 10                                      None     False      Alternate
# 11                                      None     False      Alternate
# 12  Assy, x16x16 IO Module Bracket, Improved     False           Main
# 13                                      None     False      Alternate
# 14                                      None     False      Alternate
# 15                                      None     False      Alternate
# 16                                      None     False      Alternate
# 17  Assy, x16x16 IO Module Bracket, Improved     False           Main
# 18                                      None     False      Alternate
# 19                                      None     False      Alternate
# 20                                      None     False      Alternate
# 21                                      None     False      Alternate
# 22  Assy, x16x16 IO Module Bracket, Improved     False           Main
# 23                                      None     False      Alternate
# 24                                      None     False      Alternate
# 25                                      None     False      Alternate
# 26                                      None     False      Alternate
# 27  Assy, x16x16 IO Module Bracket, Improved     False           Main
# 28                                      None     False      Alternate
# 29                                      None     False      Alternate
# 30                                      None     False      Alternate
# 31                                      None     False      Alternate
# 32  Screw, Flathead, Low thickness head, Phi     False           Main
# 33  Options, CSSD-PH2X, PCBA, 128GB Raw, 100      True           Main
# 34                                      None     False   Subcomponent
# 35                                      None     False  Sub-Alternate
# 36                                      None     False   Subcomponent
# 37                                      None     False  Sub-Alternate
# 38                                      None     False   Subcomponent
# 39                                      None     False  Sub-Alternate
# 40                                      None     False  Sub-Alternate
# 41                                      None     False  Sub-Alternate
# 42                                      None     False  Sub-Alternate
# 43                                      None     False   Subcomponent
# 44                                      None     False  Sub-Alternate
# 45                                      None     False  Sub-Alternate
# 46                                      None     False  Sub-Alternate
# 47                                      None     False  Sub-Alternate
# 48                                      None     False   Subcomponent
# 49                                      None     False  Sub-Alternate
#
#       Alternate Of
# 0             None
# 1             None
# 2             None
# 3             None
# 4       1112593-02
# 5             None
# 6   1112593-02-FLG
# 7             None
# 8          1134400
# 9          1134400
# 10         1134400
# 11         1134400
# 12            None
# 13      1134400-01
# 14      1134400-01
# 15      1134400-01
# 16      1134400-01
# 17            None
# 18  1134400-01-FGZ
# 19  1134400-01-FGZ
# 20  1134400-01-FGZ
# 21  1134400-01-FGZ
# 22            None
# 23  1134400-01-FLG
# 24  1134400-01-FLG
# 25  1134400-01-FLG
# 26  1134400-01-FLG
# 27            None
# 28     1134400-FLG
# 29     1134400-FLG
# 30     1134400-FLG
# 31     1134400-FLG
# 32            None
# 33            None
# 34            None
# 35      1112593-02
# 36            None
# 37  1112593-02-FLG
# 38            None
# 39         1134400
# 40         1134400
# 41         1134400
# 42         1134400
# 43            None
# 44      1134400-01
# 45      1134400-01
# 46      1134400-01
# 47      1134400-01
# 48            None
# 49  1134400-01-FGZ

# %%
import utils.helper_function as hf
query = '''
                    SELECT model_id, model_desc
                    FROM manufacturing_workorderdetail wo
                    WHERE workorder_id = '000007005634' and required_qty != 0
                    '''
df = hf.db_connect(query)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import utils.helper_function as hf
#       2 query = '''
#       3                     SELECT model_id, model_desc
#       4                     FROM manufacturing_workorderdetail wo
#       5                     WHERE workorder_id = '000007005634' and required_qty != 0
#       6                     '''
#       7 df = hf.db_connect(query)
#
# ModuleNotFoundError: No module named 'utils'

# %%
impo
